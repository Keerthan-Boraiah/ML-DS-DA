# %% [markdown]
# # Customer  Life Time value (CLTV) (New)

# %%
import pandas as pd
import numpy as np
import warnings
import random
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import math
from math import sqrt
from keras.models import Sequential
from keras.layers import Dense
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error 
import statsmodels.api as sm
from statsmodels.tsa.arima.model import ARIMA
from scipy import stats

# %%
warnings.filterwarnings('ignore')

# %%
New_data = pd.read_csv('New_final.csv').drop('Unnamed: 0',axis = 1)

# %%
New_data
# Out:
#        Member_number        Date        itemDescription  Sales  Year
# 0               1808  2015-07-21         tropical fruit   7.95  2015
# 1               2552  2015-05-01             whole milk  25.92  2015
# 2               2300  2015-09-19              pip fruit   8.96  2015
# 3               1187  2015-12-12       other vegetables  32.20  2015
# 4               3037  2015-01-02             whole milk  12.96  2015
# ...              ...         ...                    ...    ...   ...
# 38760           4471  2014-08-10          sliced cheese   7.12  2014
# 38761           2022  2014-02-23                  candy  11.00  2014
# 38762           1097  2014-04-16               cake bar   9.90  2014
# 38763           1510  2014-03-12  fruit/vegetable juice   2.21  2014
# 38764           1521  2014-12-26               cat food  44.00  2014
#
# [38765 rows x 5 columns]

# %% [markdown]
# # Data Preprocessing

# %%
#Data was imported after preprocessing, still checking them once to make sure if the data is processed for fitting

# %%
#Check Null values
New_data.isnull().sum()
# Out:
# Member_number      0
# Date               0
# itemDescription    0
# Sales              0
# Year               0
# dtype: int64

# %%
#Check Duplicates
New_data.duplicated().sum()
# Out:
# 124

# %%
#Not dropping duplicates cause duplicates must not be dropped in time series data as it causes temporal aggregation

# %%
#check outlier
New_data.boxplot(figsize = (10,10))
# Out:
# <AxesSubplot:>

# %%
#Checking skweness of the data
New_data.hist()
# Out:
# array([[<AxesSubplot:title={'center':'Member_number'}>,
#         <AxesSubplot:title={'center':'Sales'}>],
#        [<AxesSubplot:title={'center':'Year'}>, <AxesSubplot:>]],
#       dtype=object)

# %%
#checking summary
New_data.describe().transpose()
# Out:
#                  count         mean          std      min     25%      50%  \
# Member_number  38765.0  3003.641868  1153.611031  1000.00  2002.0  3005.00
# Sales          38765.0    15.812160    16.544494     0.33     5.7    11.13
# Year           38765.0  2014.528518     0.499193  2014.00  2014.0  2015.00
#
#                    75%     max
# Member_number  4007.00  5000.0
# Sales            20.93   400.0
# Year           2015.00  2015.0

# %%
#Checking dtypes
New_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 38765 entries, 0 to 38764
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Member_number    38765 non-null  int64
#  1   Date             38765 non-null  object
#  2   itemDescription  38765 non-null  object
#  3   Sales            38765 non-null  float64
#  4   Year             38765 non-null  int64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 1.5+ MB

# %%
#Converting object to datetime
New_data['Date'] = pd.to_datetime(New_data['Date'])

# %%
New_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 38765 entries, 0 to 38764
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Member_number    38765 non-null  int64
#  1   Date             38765 non-null  datetime64[ns]
#  2   itemDescription  38765 non-null  object
#  3   Sales            38765 non-null  float64
#  4   Year             38765 non-null  int64
# dtypes: datetime64[ns](1), float64(1), int64(2), object(1)
# memory usage: 1.5+ MB

# %%
New_data.head()
# Out:
#    Member_number       Date   itemDescription  Sales  Year
# 0           1808 2015-07-21    tropical fruit   7.95  2015
# 1           2552 2015-05-01        whole milk  25.92  2015
# 2           2300 2015-09-19         pip fruit   8.96  2015
# 3           1187 2015-12-12  other vegetables  32.20  2015
# 4           3037 2015-01-02        whole milk  12.96  2015

# %%
#Checking if data is stationary or not
from statsmodels.tsa.stattools import adfuller

# Plot the time series data
plt.figure(figsize=(12, 6))
plt.plot(New_data['Sales'])
plt.title('Time Series Data')
plt.xlabel('Time')
plt.ylabel('Sales')
plt.show()

# Perform the Augmented Dickey-Fuller test
result = adfuller(New_data['Sales'])

# Extract and print the test results
print('ADF Statistic:', result[0])
print('p-value:', result[1])
print('Critical Values:')
for key, value in result[4].items():
    print(f'{key}: {value}')

# Interpret the test results
if result[1] <= 0.05:
    print("The time series is stationary (reject the null hypothesis)")
else:
    print("The time series is not stationary (fail to reject the null hypothesis)")
# Out:
# ADF Statistic: -195.4537736663755
# p-value: 0.0
# Critical Values:
# 1%: -3.430518706353408
# 5%: -2.8616145642671476
# 10%: -2.56680968817625
# The time series is stationary (reject the null hypothesis)

# %%
#Checking Correlation (Feature) (Useless to be honest cause we dont have much attributes)
New_data.corr()
# Out:
#                Member_number     Sales      Year
# Member_number       1.000000  0.003764 -0.003019
# Sales               0.003764  1.000000 -0.002481
# Year               -0.003019 -0.002481  1.000000

# %%
sns.heatmap(New_data.corr(), annot = True)
# Out:
# <AxesSubplot:>

# %%
New_data['Member_number'].nunique()
# Out:
# 3898

# %%
New_data['itemDescription'].nunique()
# Out:
# 167

# %%
New_data['itemDescription'].unique()
# Out:
# array(['tropical fruit', 'whole milk', 'pip fruit', 'other vegetables',
#        'rolls/buns', 'pot plants', 'citrus fruit', 'beef', 'frankfurter',
#        'chicken', 'butter', 'fruit/vegetable juice',
#        'packaged fruit/vegetables', 'chocolate', 'specialty bar',
#        'butter milk', 'bottled water', 'yogurt', 'sausage', 'brown bread',
#        'hamburger meat', 'root vegetables', 'pork', 'pastry',
#        'canned beer', 'berries', 'coffee', 'misc. beverages', 'ham',
#        'turkey', 'curd cheese', 'red/blush wine',
#        'frozen potato products', 'flour', 'sugar', 'frozen meals',
#        'herbs', 'soda', 'detergent', 'grapes', 'processed cheese', 'fish',
#        'sparkling wine', 'newspapers', 'curd', 'pasta', 'popcorn',
#        'finished products', 'beverages', 'bottled beer', 'dessert',
#        'dog food', 'specialty chocolate', 'condensed milk', 'cleaner',
#        'white wine', 'meat', 'ice cream', 'hard cheese', 'cream cheese ',
#        'liquor', 'pickled vegetables', 'liquor (appetizer)', 'UHT-milk',
#        'candy', 'onions', 'hair spray', 'photo/film', 'domestic eggs',
#        'margarine', 'shopping bags', 'salt', 'oil', 'whipped/sour cream',
#        'frozen vegetables', 'sliced cheese', 'dish cleaner',
#        'baking powder', 'specialty cheese', 'salty snack',
#        'Instant food products', 'pet care', 'white bread',
#        'female sanitary products', 'cling film/bags', 'soap',
#        'frozen chicken', 'house keeping products', 'spread cheese',
#        'decalcifier', 'frozen dessert', 'vinegar', 'nuts/prunes',
#        'potato products', 'frozen fish', 'hygiene articles',
#        'artif. sweetener', 'light bulbs', 'canned vegetables',
#        'chewing gum', 'canned fish', 'cookware', 'semi-finished bread',
#        'cat food', 'bathroom cleaner', 'prosecco', 'liver loaf',
#        'zwieback', 'canned fruit', 'frozen fruits', 'brandy',
#        'baby cosmetics', 'spices', 'napkins', 'waffles', 'sauces', 'rum',
#        'chocolate marshmallow', 'long life bakery product', 'bags',
#        'sweet spreads', 'soups', 'mustard', 'specialty fat',
#        'instant coffee', 'snack products', 'organic sausage',
#        'soft cheese', 'mayonnaise', 'dental care', 'roll products ',
#        'kitchen towels', 'flower soil/fertilizer', 'cereals',
#        'meat spreads', 'dishes', 'male cosmetics', 'candles', 'whisky',
#        'tidbits', 'cooking chocolate', 'seasonal products', 'liqueur',
#        'abrasive cleaner', 'syrup', 'ketchup', 'cream', 'skin care',
#        'rubbing alcohol', 'nut snack', 'cocoa drinks', 'softener',
#        'organic products', 'cake bar', 'honey', 'jam', 'kitchen utensil',
#        'flower (seeds)', 'rice', 'tea', 'salad dressing',
#        'specialty vegetables', 'pudding powder', 'ready soups',
#        'make up remover', 'toilet cleaner', 'preservation products'],
#       dtype=object)

# %%
New_data['Member_number'].unique()
# Out:
# array([1808, 2552, 2300, ..., 3607, 4587, 2417], dtype=int64)

# %%
New_data['Year'].unique()
# Out:
# array([2015, 2014], dtype=int64)

# %%
#Select only Customers who has more than 10 transcations recorded
selected_members_10 = []
for i in New_data['Member_number'].unique():
    if len(New_data[New_data['Member_number'] == i])>10:
        selected_members_10.append(i)

# %%
#Select only Customers who has more than 20 transcations recorded
selected_members_20 = []
for i in New_data['Member_number'].unique():
    if len(New_data[New_data['Member_number'] == i])>20:
        selected_members_20.append(i)

# %%
#Original Customers
New_data['Member_number'].nunique()
# Out:
# 3898

# %%
#Only Customers with more than 10 transactions
len(selected_members_10)
# Out:
# 1598

# %%
#Only Customers with more than 20 transactions
len(selected_members_20)
# Out:
# 161

# %%
selected_members_20[0:5]
# Out:
# [4941, 2193, 1997, 2421, 1905]

# %%
Final_data = pd.DataFrame()
for i in selected_members_20:
    Final_data = Final_data.append(New_data[New_data['Member_number'] == i])
Final_data.reset_index(inplace = True,drop = True)

# %%
Final_data
# Out:
#       Member_number       Date     itemDescription  Sales  Year
# 0              4941 2015-02-14          rolls/buns   7.20  2015
# 1              4941 2015-01-15          rolls/buns   7.20  2015
# 2              4941 2015-01-15         canned beer   8.55  2015
# 3              4941 2015-01-15        bottled beer  70.00  2015
# 4              4941 2015-01-15                 ham  19.04  2015
# ...             ...        ...                 ...    ...   ...
# 3803           1169 2014-05-29  whipped/sour cream   5.70  2014
# 3804           1169 2014-01-25         white bread   4.50  2014
# 3805           1169 2014-04-15             napkins   3.28  2014
# 3806           1169 2014-05-06             cleaner  60.00  2014
# 3807           1169 2014-12-15        bottled beer  20.00  2014
#
# [3808 rows x 5 columns]

# %%
Final_data['Member_number'].nunique()
# Out:
# 161

# %%
Final_data[Final_data['Member_number'] == 4941]
# Out:
#     Member_number       Date        itemDescription  Sales  Year
# 0            4941 2015-02-14             rolls/buns   7.20  2015
# 1            4941 2015-01-15             rolls/buns   7.20  2015
# 2            4941 2015-01-15            canned beer   8.55  2015
# 3            4941 2015-01-15           bottled beer  70.00  2015
# 4            4941 2015-01-15                    ham  19.04  2015
# 5            4941 2014-09-09                 coffee   2.70  2014
# 6            4941 2014-12-06             whole milk  21.60  2014
# 7            4941 2014-04-13                 liquor  23.80  2014
# 8            4941 2014-08-02                 yogurt  16.10  2014
# 9            4941 2014-02-24             white wine  14.00  2014
# 10           4941 2014-08-13                   meat  40.00  2014
# 11           4941 2015-02-14           citrus fruit   9.60  2015
# 12           4941 2015-01-15         hamburger meat  34.30  2015
# 13           4941 2015-01-15     pickled vegetables   3.78  2015
# 14           4941 2015-01-15            salty snack   3.00  2015
# 15           4941 2015-01-15          domestic eggs   6.63  2015
# 16           4941 2014-09-09                   soda  12.60  2014
# 17           4941 2014-12-06            canned beer   8.55  2014
# 18           4941 2014-04-13             newspapers   3.00  2014
# 19           4941 2014-08-02                  pasta   9.80  2014
# 20           4941 2014-02-24                   soda  29.40  2014
# 21           4941 2014-08-13            butter milk  17.08  2014
# 22           4941 2014-10-25            white bread   7.50  2014
# 23           4941 2015-01-15                   soda   8.40  2015
# 24           4941 2015-02-14  fruit/vegetable juice   4.42  2015
# 25           4941 2014-10-25  chocolate marshmallow   3.63  2014

# %%
len(selected_members_20)
# Out:
# 161

# %% [markdown]
# # Model Performances

# %%
model_1 = []
model_2 = []
model_3 = []
model_4 = []

# %% [markdown]
# # ARIMA Model (Auto-Regression Integrated Moving Average)

# %%
Error = []
for i in selected_members_20:
    a = Final_data[Final_data['Member_number'] == i]
    
    model = ARIMA(a['Sales'].iloc[0:-2])
    model_fit = model.fit()
    
    #Forcast
    ypred = model_fit.forecast(2)
    
    Error.append(np.sqrt(mean_squared_error(np.array(a['Sales'].iloc[-2:]), np.array(ypred))))

# %%
#Original for customer 4921
a['Sales'].iloc[-2:]
# Out:
# 3806    60.0
# 3807    20.0
# Name: Sales, dtype: float64

# %% [markdown]
# # Predicted/Forecasted

# %%
#Forcasted for customer 4921
ypred
# Out:
# 19    14.3621
# 20    14.3621
# Name: predicted_mean, dtype: float64

# %%
#RMSE for customer 4921
np.sqrt(mean_squared_error(np.array(a['Sales'].iloc[-2:]), np.array(ypred)))
# Out:
# 32.51617914761352

# %%
for i in range(len(Error)):
    print('The RMSE for Forcasted Customer',selected_members_20[i],'is',Error[i])
# Out:
# The RMSE for Forcasted Customer 4941 is 11.974430366258867
# The RMSE for Forcasted Customer 2193 is 8.8362389285867
# The RMSE for Forcasted Customer 1997 is 9.01953765523751
# The RMSE for Forcasted Customer 2421 is 12.428152640300464
# The RMSE for Forcasted Customer 1905 is 8.766082323130163
# The RMSE for Forcasted Customer 4783 is 14.1647100718013
# The RMSE for Forcasted Customer 3709 is 21.24330907945537
# The RMSE for Forcasted Customer 4272 is 9.305697413959948
# The RMSE for Forcasted Customer 2632 is 11.149163512693693
# The RMSE for Forcasted Customer 2270 is 14.625245049928953
# The RMSE for Forcasted Customer 3811 is 6.389020292537512
# The RMSE for Forcasted Customer 4875 is 11.746683831838821
# The RMSE for Forcasted Customer 2022 is 5.389648003320452
# The RMSE for Forcasted Customer 4293 is 51.61657026705207
# The RMSE for Forcasted Customer 2560 is 22.89048050465031
# The RMSE for Forcasted Customer 2990 is 10.688028669929505
# The RMSE for Forcasted Customer 3635 is 12.766181295520214
# The RMSE for Forcasted Customer 3915 is 5.572759850958588
# The RMSE for Forcasted Customer 4828 is 10.05522580252529
# The RMSE for Forcasted Customer 3221 is 13.400862971430897
# The RMSE for Forcasted Customer 4338 is 3.702350978603238
# The RMSE for Forcasted Customer 2851 is 9.636366176428051
# The RMSE for Forcasted Customer 2184 is 10.122744355467546
# The RMSE for Forcasted Customer 3361 is 12.85072442624561
# The RMSE for Forcasted Customer 3783 is 9.366593327461462
# The RMSE for Forcasted Customer 3942 is 47.418307723730834
# The RMSE for Forcasted Customer 4187 is 9.823073241014516
# The RMSE for Forcasted Customer 2760 is 21.660580040307117
# The RMSE for Forcasted Customer 2443 is 17.651814797441336
# The RMSE for Forcasted Customer 4494 is 7.5479593380908145
# The RMSE for Forcasted Customer 1395 is 11.37786131477257
# The RMSE for Forcasted Customer 2229 is 9.901788384778728
# The RMSE for Forcasted Customer 3679 is 0.19632060472671853
# The RMSE for Forcasted Customer 3495 is 9.891689197631552
# The RMSE for Forcasted Customer 1410 is 18.517251850403937
# The RMSE for Forcasted Customer 2440 is 71.31493718332464
# The RMSE for Forcasted Customer 2447 is 8.523083053831964
# The RMSE for Forcasted Customer 4217 is 26.679616023704586
# The RMSE for Forcasted Customer 2816 is 3.9363516099764815
# The RMSE for Forcasted Customer 3543 is 5.073054814684546
# The RMSE for Forcasted Customer 4524 is 7.699522765655631
# The RMSE for Forcasted Customer 3180 is 0.9545409581473393
# The RMSE for Forcasted Customer 3737 is 16.312601302735718
# The RMSE for Forcasted Customer 1466 is 12.536392615713018
# The RMSE for Forcasted Customer 3960 is 8.738114475813088
# The RMSE for Forcasted Customer 3246 is 6.687715597108702
# The RMSE for Forcasted Customer 4486 is 7.635764517266163
# The RMSE for Forcasted Customer 3484 is 14.795845887948088
# The RMSE for Forcasted Customer 2799 is 11.073322143239182
# The RMSE for Forcasted Customer 2294 is 8.13916187966544
# The RMSE for Forcasted Customer 3120 is 14.320044466982624
# The RMSE for Forcasted Customer 3872 is 10.879455695348412
# The RMSE for Forcasted Customer 2394 is 3.9371602838620103
# The RMSE for Forcasted Customer 3593 is 9.249075953425983
# The RMSE for Forcasted Customer 4864 is 11.204837322253764
# The RMSE for Forcasted Customer 1737 is 9.797569084425596
# The RMSE for Forcasted Customer 4437 is 4.646475610055407
# The RMSE for Forcasted Customer 2524 is 18.821373756821522
# The RMSE for Forcasted Customer 3090 is 48.932296852024145
# The RMSE for Forcasted Customer 1827 is 4.106052548423301
# The RMSE for Forcasted Customer 4683 is 29.028585847809648
# The RMSE for Forcasted Customer 3752 is 22.075116460692556
# The RMSE for Forcasted Customer 3497 is 7.862821273279898
# The RMSE for Forcasted Customer 4303 is 25.2791625258779
# The RMSE for Forcasted Customer 3164 is 2.0914998570481944
# The RMSE for Forcasted Customer 3122 is 10.63656994737711
# The RMSE for Forcasted Customer 1366 is 10.237482618612363
# The RMSE for Forcasted Customer 1225 is 13.843866755729497
# The RMSE for Forcasted Customer 2070 is 6.675786466422919
# The RMSE for Forcasted Customer 1574 is 8.848942427172668
# The RMSE for Forcasted Customer 1379 is 5.451288790125531
# The RMSE for Forcasted Customer 1929 is 4.3536365031795015
# The RMSE for Forcasted Customer 2517 is 8.200312632120866
# The RMSE for Forcasted Customer 2918 is 9.93957891763977
# The RMSE for Forcasted Customer 1780 is 10.584659330252169
# The RMSE for Forcasted Customer 1566 is 31.482378204953744
# The RMSE for Forcasted Customer 2344 is 7.98117685527343
# The RMSE for Forcasted Customer 2868 is 8.611144704469444
# The RMSE for Forcasted Customer 3289 is 12.702444805392561
# The RMSE for Forcasted Customer 3465 is 22.081124887631237
# The RMSE for Forcasted Customer 2511 is 17.65261075560476
# The RMSE for Forcasted Customer 3050 is 13.983223859387696
# The RMSE for Forcasted Customer 4695 is 7.00601596866488
# The RMSE for Forcasted Customer 2625 is 11.051723665167495
# The RMSE for Forcasted Customer 2492 is 31.00793730652274
# The RMSE for Forcasted Customer 3835 is 13.957626335437189
# The RMSE for Forcasted Customer 4251 is 26.480131762704143
# The RMSE for Forcasted Customer 1793 is 7.833078721601551
# The RMSE for Forcasted Customer 4495 is 11.22899155255158
# The RMSE for Forcasted Customer 1878 is 17.69839143610157
# The RMSE for Forcasted Customer 3251 is 2.7750450573040144
# The RMSE for Forcasted Customer 3761 is 6.7905571675553285
# The RMSE for Forcasted Customer 2960 is 14.931269093843394
# The RMSE for Forcasted Customer 4574 is 10.835374406649885
# The RMSE for Forcasted Customer 1275 is 7.040435838127162
# The RMSE for Forcasted Customer 4877 is 19.471133611808924
# The RMSE for Forcasted Customer 3957 is 17.124140708816306
# The RMSE for Forcasted Customer 2234 is 6.337536644786954
# The RMSE for Forcasted Customer 3732 is 20.773290713007523
# The RMSE for Forcasted Customer 4831 is 16.35792601874432
# The RMSE for Forcasted Customer 2855 is 10.424200471268955
# The RMSE for Forcasted Customer 4137 is 5.776088743628736
# The RMSE for Forcasted Customer 3248 is 13.165343536026008
# The RMSE for Forcasted Customer 3266 is 7.172529386221369
# The RMSE for Forcasted Customer 3082 is 45.17617666660349
# The RMSE for Forcasted Customer 2736 is 6.33289573931364
# The RMSE for Forcasted Customer 3046 is 9.5387622967657
# The RMSE for Forcasted Customer 1948 is 12.572000100738538
# The RMSE for Forcasted Customer 4585 is 9.654702622778085
# The RMSE for Forcasted Customer 1353 is 11.525109785810313
# The RMSE for Forcasted Customer 3247 is 13.302294385075825
# The RMSE for Forcasted Customer 2433 is 8.323181241158295
# The RMSE for Forcasted Customer 3691 is 16.11475934604681
# The RMSE for Forcasted Customer 1407 is 17.771265544581752
# The RMSE for Forcasted Customer 1595 is 11.558124966004758
# The RMSE for Forcasted Customer 1265 is 8.284232667724282
# The RMSE for Forcasted Customer 2779 is 10.742009917468184
# The RMSE for Forcasted Customer 2512 is 13.869229567346986
# The RMSE for Forcasted Customer 1098 is 21.346252048560036
# The RMSE for Forcasted Customer 3651 is 10.09584100190322
# The RMSE for Forcasted Customer 4588 is 20.724106661357077
# The RMSE for Forcasted Customer 1998 is 20.190510698301104
# The RMSE for Forcasted Customer 4277 is 12.945451566518644
# The RMSE for Forcasted Customer 2051 is 18.143178161804805
# The RMSE for Forcasted Customer 2271 is 2.311029161838327
# The RMSE for Forcasted Customer 3517 is 7.002801391234407
# The RMSE for Forcasted Customer 3462 is 5.809629234467318
# The RMSE for Forcasted Customer 1887 is 8.835402058317122
# The RMSE for Forcasted Customer 1116 is 9.468460461851603
# The RMSE for Forcasted Customer 4376 is 7.997466091386226
# The RMSE for Forcasted Customer 4153 is 8.615196354601899
# The RMSE for Forcasted Customer 4671 is 13.055547574638695
# The RMSE for Forcasted Customer 1087 is 10.367368541664051
# The RMSE for Forcasted Customer 3042 is 9.090773804595951
# The RMSE for Forcasted Customer 4933 is 9.591126115565343
# The RMSE for Forcasted Customer 4656 is 15.65081958885831
# The RMSE for Forcasted Customer 1218 is 5.467230967666661
# The RMSE for Forcasted Customer 1654 is 24.75131243758963
# The RMSE for Forcasted Customer 4753 is 4.759593578877049
# The RMSE for Forcasted Customer 2789 is 10.244178811549428
# The RMSE for Forcasted Customer 2408 is 24.575574883184675
# The RMSE for Forcasted Customer 2738 is 15.84018468772413
# The RMSE for Forcasted Customer 2706 is 48.342145511407516
# The RMSE for Forcasted Customer 3402 is 10.801734070883835
# The RMSE for Forcasted Customer 1991 is 5.5096927762950125
# The RMSE for Forcasted Customer 3830 is 8.650067105892935
# The RMSE for Forcasted Customer 2663 is 9.67746134815696
# The RMSE for Forcasted Customer 2164 is 0.5705734703327502
# The RMSE for Forcasted Customer 4364 is 9.355462490359061
# The RMSE for Forcasted Customer 3862 is 11.610571593083572
# The RMSE for Forcasted Customer 1870 is 4.206782714366534
# The RMSE for Forcasted Customer 1583 is 5.947495243464173
# The RMSE for Forcasted Customer 4190 is 12.617908802366735
# The RMSE for Forcasted Customer 4679 is 10.665253474568734
# The RMSE for Forcasted Customer 3308 is 6.455128938447696
# The RMSE for Forcasted Customer 1052 is 9.25548308104393
# The RMSE for Forcasted Customer 1004 is 16.80097924282822
# The RMSE for Forcasted Customer 4624 is 33.528320679036206
# The RMSE for Forcasted Customer 2252 is 11.759195360254934
# The RMSE for Forcasted Customer 4297 is 28.64394081262041
# The RMSE for Forcasted Customer 1169 is 32.51617914761352

# %%
#Total Rmse for All Customer
print('The Total RMSE of All Customer is for ARIMA:-',sum(Error)/len(Error))
# Out:
# The Total RMSE of All Customer is for ARIMA:- 13.422907825203396

# %%
model_1.append(sum(Error)/len(Error))

# %% [markdown]
# ### Random Model RMSE Check to wheather our CLTV model is forecasting usefull

# %%
A = pd.DataFrame()
for i in selected_members_20:
    A = A.append(Final_data[Final_data['Member_number'] == i])

A.describe()
# Out:
#        Member_number        Sales         Year
# count     3808.00000  3808.000000  3808.000000
# mean      3043.90730    15.850097  2014.600578
# std       1093.83799    15.168624     0.489844
# min       1004.00000     0.330000  2014.000000
# 25%       2193.00000     5.700000  2014.000000
# 50%       3050.00000    11.130000  2015.000000
# 75%       3915.00000    21.000000  2015.000000
# max       4941.00000   120.000000  2015.000000

# %%
#Creating Random values to check the rsme of the algorithm prediction
random_error = []
random_values = pd.DataFrame(index = range(190*20))
random_values['Member_number'] = 0
random_values['Sales'] = 0
random_values['Year'] = 2014

twenties = []
count = 1

for i in range(random_values.shape[0]):
    if i == 0:
        continue
    else:
        if 20*i> random_values.shape[0]:
            break
        else:
            twenties.append(20*i)
            
for i in range(random_values.shape[0]):
    if i+1==twenties[0]:
        random_values['Member_number'][i] = count
        del twenties[0]
        count = count +1
    else:
        random_values['Member_number'][i] = count
        
original_data = Final_data.Sales
kde = stats.gaussian_kde(original_data)
num_samples = 3800  # Set the number of random samples you want to generate
random_numbers = kde.resample(num_samples)
random_numbers = sum(random_numbers.tolist(),[])

random_values['Sales'] = random_numbers

# %%
for i in range(162):
    if i ==0:
        continue
    else:
        a = random_values[random_values['Member_number'] == i]
    
        model = ARIMA(a['Sales'].iloc[0:-2], order = (1,1,1))
        model_fit = model.fit()
    
        #Forcast
        ypred = model_fit.forecast(2)
    
        random_error.append(np.sqrt(mean_squared_error(np.array(a['Sales'].iloc[-2:]), np.array(ypred))))

# %%
#Total Rmse for ARIMA Random Model
print('The Total RMSE of All Customer is for ARIMA RANDOM:-',sum(random_error)/len(random_error))
# Out:
# The Total RMSE of All Customer is for ARIMA RANDOM:- 13.019166886338178

# %%
def create_line_plot(x_values, y_values):
    plt.plot(x_values, y_values)
    plt.xlabel('X-axis')
    plt.ylabel('Y-axis')
    plt.title('RMSE Plot')
    plt.show()

# Example data
y_values = []
for i in range(len(Error)):
    y_values.append(i)
    
y_values1 = []
for i in range(len(random_error)):
    y_values1.append(i)

# %%
#ARIMA Error Plot
create_line_plot(y_values,Error)

# %%
#ARIMA Random Error Plot
create_line_plot(y_values1,random_error)

# %% [markdown]
# # SES Model (Single Exponential Smoothing)

# %%
from statsmodels.tsa.holtwinters import ExponentialSmoothing

# %%
Error1 = []
for i in selected_members_20:
    a = Final_data[Final_data['Member_number'] == i]
    
    model = ExponentialSmoothing(a['Sales'].iloc[0:-2])
    ypred = model_fit.forecast(2)
    
    Error1.append(np.sqrt(mean_squared_error(np.array(a['Sales'].iloc[-2:]), np.array(ypred))))

# %%
for i in range(len(Error1)):
    print('The RMSE for Forcasted Customer',selected_members_20[i],'is',Error1[i])
# Out:
# The RMSE for Forcasted Customer 4941 is 1.0601959497137283
# The RMSE for Forcasted Customer 2193 is 10.618496354552567
# The RMSE for Forcasted Customer 1997 is 11.369419502917948
# The RMSE for Forcasted Customer 2421 is 19.173584623192074
# The RMSE for Forcasted Customer 1905 is 2.987853514094306
# The RMSE for Forcasted Customer 4783 is 1.4492188691550127
# The RMSE for Forcasted Customer 3709 is 31.24787314807205
# The RMSE for Forcasted Customer 4272 is 11.99272318317907
# The RMSE for Forcasted Customer 2632 is 12.131595601272531
# The RMSE for Forcasted Customer 2270 is 2.134606638417921
# The RMSE for Forcasted Customer 3811 is 1.7934481773920248
# The RMSE for Forcasted Customer 4875 is 3.3846409473486077
# The RMSE for Forcasted Customer 2022 is 8.817637945883865
# The RMSE for Forcasted Customer 4293 is 56.84971275578319
# The RMSE for Forcasted Customer 2560 is 31.80251822814652
# The RMSE for Forcasted Customer 2990 is 19.154566084846955
# The RMSE for Forcasted Customer 3635 is 21.415405852131233
# The RMSE for Forcasted Customer 3915 is 11.803243382144066
# The RMSE for Forcasted Customer 4828 is 11.381885573737021
# The RMSE for Forcasted Customer 3221 is 6.334142120871746
# The RMSE for Forcasted Customer 4338 is 6.623666693417362
# The RMSE for Forcasted Customer 2851 is 16.10082060192203
# The RMSE for Forcasted Customer 2184 is 11.76035402864814
# The RMSE for Forcasted Customer 3361 is 26.91911088552895
# The RMSE for Forcasted Customer 3783 is 15.930233249439615
# The RMSE for Forcasted Customer 3942 is 57.42074428109584
# The RMSE for Forcasted Customer 4187 is 5.598142969132169
# The RMSE for Forcasted Customer 2760 is 26.176035802005003
# The RMSE for Forcasted Customer 2443 is 23.650166337332777
# The RMSE for Forcasted Customer 4494 is 6.411283236968087
# The RMSE for Forcasted Customer 1395 is 4.4452284943613165
# The RMSE for Forcasted Customer 2229 is 3.7269468150653906
# The RMSE for Forcasted Customer 3679 is 8.231555480762676
# The RMSE for Forcasted Customer 3495 is 1.963250454449143
# The RMSE for Forcasted Customer 1410 is 28.46279030915938
# The RMSE for Forcasted Customer 2440 is 82.39668082792603
# The RMSE for Forcasted Customer 2447 is 2.44775976343721
# The RMSE for Forcasted Customer 4217 is 31.9201349747456
# The RMSE for Forcasted Customer 2816 is 9.759905287362377
# The RMSE for Forcasted Customer 3543 is 11.65238230235911
# The RMSE for Forcasted Customer 4524 is 4.623858415361323
# The RMSE for Forcasted Customer 3180 is 6.221383875813588
# The RMSE for Forcasted Customer 3737 is 21.686627880179927
# The RMSE for Forcasted Customer 1466 is 2.0560742363531976
# The RMSE for Forcasted Customer 3960 is 1.5151742582695609
# The RMSE for Forcasted Customer 3246 is 7.9443510535216255
# The RMSE for Forcasted Customer 4486 is 4.182531693004523
# The RMSE for Forcasted Customer 3484 is 20.469624772703227
# The RMSE for Forcasted Customer 2799 is 17.8914425456517
# The RMSE for Forcasted Customer 2294 is 12.968636096880727
# The RMSE for Forcasted Customer 3120 is 2.844758287625812
# The RMSE for Forcasted Customer 3872 is 2.7891050204635186
# The RMSE for Forcasted Customer 2394 is 7.402800137773219
# The RMSE for Forcasted Customer 3593 is 6.404446242375466
# The RMSE for Forcasted Customer 4864 is 22.693047327109987
# The RMSE for Forcasted Customer 1737 is 3.932848963520165
# The RMSE for Forcasted Customer 4437 is 15.989282456105057
# The RMSE for Forcasted Customer 2524 is 24.690956241430708
# The RMSE for Forcasted Customer 3090 is 55.48429611271404
# The RMSE for Forcasted Customer 1827 is 13.524876562070094
# The RMSE for Forcasted Customer 4683 is 36.00667288482202
# The RMSE for Forcasted Customer 3752 is 30.523342399447607
# The RMSE for Forcasted Customer 3497 is 5.571458238146623
# The RMSE for Forcasted Customer 4303 is 31.866125624097144
# The RMSE for Forcasted Customer 3164 is 8.436256532592266
# The RMSE for Forcasted Customer 3122 is 3.2845130135875453
# The RMSE for Forcasted Customer 1366 is 12.249264876644078
# The RMSE for Forcasted Customer 1225 is 3.4131168049822636
# The RMSE for Forcasted Customer 2070 is 5.432907012974258
# The RMSE for Forcasted Customer 1574 is 8.594388311850105
# The RMSE for Forcasted Customer 1379 is 4.920289609221729
# The RMSE for Forcasted Customer 1929 is 4.605735625665805
# The RMSE for Forcasted Customer 2517 is 9.64946368868153
# The RMSE for Forcasted Customer 2918 is 5.968388851666197
# The RMSE for Forcasted Customer 1780 is 2.86214534761314
# The RMSE for Forcasted Customer 1566 is 38.56022850004409
# The RMSE for Forcasted Customer 2344 is 6.000884960320076
# The RMSE for Forcasted Customer 2868 is 1.4807252478631308
# The RMSE for Forcasted Customer 3289 is 3.3541728267107964
# The RMSE for Forcasted Customer 3465 is 29.27766126587182
# The RMSE for Forcasted Customer 2511 is 2.6445386429916677
# The RMSE for Forcasted Customer 3050 is 17.814103794056038
# The RMSE for Forcasted Customer 4695 is 13.740127819965897
# The RMSE for Forcasted Customer 2625 is 1.8513562530154968
# The RMSE for Forcasted Customer 2492 is 38.6084380919854
# The RMSE for Forcasted Customer 3835 is 19.954847105622843
# The RMSE for Forcasted Customer 4251 is 36.08587639658672
# The RMSE for Forcasted Customer 1793 is 11.412905535476693
# The RMSE for Forcasted Customer 4495 is 5.446490365254257
# The RMSE for Forcasted Customer 1878 is 23.742690319328283
# The RMSE for Forcasted Customer 3251 is 8.315874746589445
# The RMSE for Forcasted Customer 3761 is 13.153694925216197
# The RMSE for Forcasted Customer 2960 is 2.7898604452215086
# The RMSE for Forcasted Customer 4574 is 18.34012690308219
# The RMSE for Forcasted Customer 1275 is 5.455267975958109
# The RMSE for Forcasted Customer 4877 is 2.3827867695030185
# The RMSE for Forcasted Customer 3957 is 3.344144370097727
# The RMSE for Forcasted Customer 2234 is 7.542617655167867
# The RMSE for Forcasted Customer 3732 is 1.4757071419130239
# The RMSE for Forcasted Customer 4831 is 29.193912710544517
# The RMSE for Forcasted Customer 2855 is 12.002365138079066
# The RMSE for Forcasted Customer 4137 is 5.443331282370214
# The RMSE for Forcasted Customer 3248 is 3.2174701030112183
# The RMSE for Forcasted Customer 3266 is 5.49343895999578
# The RMSE for Forcasted Customer 3082 is 50.07525940117784
# The RMSE for Forcasted Customer 2736 is 6.9796749737477946
# The RMSE for Forcasted Customer 3046 is 13.15980887921103
# The RMSE for Forcasted Customer 1948 is 21.91639794532344
# The RMSE for Forcasted Customer 4585 is 11.028727515521197
# The RMSE for Forcasted Customer 1353 is 2.9003379051606966
# The RMSE for Forcasted Customer 3247 is 2.670190200490647
# The RMSE for Forcasted Customer 2433 is 2.802311741527535
# The RMSE for Forcasted Customer 3691 is 26.91911088552895
# The RMSE for Forcasted Customer 1407 is 24.76619876404274
# The RMSE for Forcasted Customer 1595 is 17.927490621145946
# The RMSE for Forcasted Customer 1265 is 11.332905399359674
# The RMSE for Forcasted Customer 2779 is 24.334431766707862
# The RMSE for Forcasted Customer 2512 is 1.7017718103561672
# The RMSE for Forcasted Customer 1098 is 27.595328126716353
# The RMSE for Forcasted Customer 3651 is 13.283601317105013
# The RMSE for Forcasted Customer 4588 is 26.759227323781243
# The RMSE for Forcasted Customer 1998 is 26.188442345322713
# The RMSE for Forcasted Customer 4277 is 17.19593815168425
# The RMSE for Forcasted Customer 2051 is 24.700453048104045
# The RMSE for Forcasted Customer 2271 is 9.081581105232447
# The RMSE for Forcasted Customer 3517 is 7.467057925130965
# The RMSE for Forcasted Customer 3462 is 10.823076589103037
# The RMSE for Forcasted Customer 1887 is 3.0757895549178733
# The RMSE for Forcasted Customer 1116 is 13.31631088925175
# The RMSE for Forcasted Customer 4376 is 2.8339618076250828
# The RMSE for Forcasted Customer 4153 is 7.313563071413439
# The RMSE for Forcasted Customer 4671 is 4.3110340550950905
# The RMSE for Forcasted Customer 1087 is 2.7705678023840195
# The RMSE for Forcasted Customer 3042 is 15.264546558107954
# The RMSE for Forcasted Customer 4933 is 2.6577692164542674
# The RMSE for Forcasted Customer 4656 is 12.913256944571085
# The RMSE for Forcasted Customer 1218 is 13.289518280638761
# The RMSE for Forcasted Customer 1654 is 31.791034746117266
# The RMSE for Forcasted Customer 4753 is 9.42820032669781
# The RMSE for Forcasted Customer 2789 is 2.802853076524805
# The RMSE for Forcasted Customer 2408 is 30.56948178906836
# The RMSE for Forcasted Customer 2738 is 20.144236926644044
# The RMSE for Forcasted Customer 2706 is 55.41352334656208
# The RMSE for Forcasted Customer 3402 is 3.6287257981781957
# The RMSE for Forcasted Customer 1991 is 11.803243382144066
# The RMSE for Forcasted Customer 3830 is 6.662046062162441
# The RMSE for Forcasted Customer 2663 is 10.69994200601095
# The RMSE for Forcasted Customer 2164 is 5.111204973810536
# The RMSE for Forcasted Customer 4364 is 2.0528238189776635
# The RMSE for Forcasted Customer 3862 is 1.470087423917051
# The RMSE for Forcasted Customer 1870 is 5.006786034662736
# The RMSE for Forcasted Customer 1583 is 10.823076589103037
# The RMSE for Forcasted Customer 4190 is 2.949275390515626
# The RMSE for Forcasted Customer 4679 is 4.037044036048998
# The RMSE for Forcasted Customer 3308 is 14.041237100004821
# The RMSE for Forcasted Customer 1052 is 5.229136142483092
# The RMSE for Forcasted Customer 1004 is 25.346832522982492
# The RMSE for Forcasted Customer 4624 is 38.48622621913879
# The RMSE for Forcasted Customer 2252 is 2.7979358541426853
# The RMSE for Forcasted Customer 4297 is 38.56602728744868
# The RMSE for Forcasted Customer 1169 is 40.260017693023464

# %%
#Total Rmse for All Customer
print('The Total RMSE of All Customer is for SES-',sum(Error1)/len(Error1))
# Out:
# The Total RMSE of All Customer is for SES- 14.247220117820143

# %%
model_2.append(sum(Error1)/len(Error1))

# %% [markdown]
# ### Random Model RMSE Check to wheather our CLTV model is forecasting usefull

# %%
random_error1 = []
for i in range(162):
    if i ==0:
        continue
    else:
        a = random_values[random_values['Member_number'] == i]
    
        model = ExponentialSmoothing(a['Sales'].iloc[0:-2])
        model_fit = model.fit()
    
        #Forcast
        ypred = model_fit.forecast(2)
    
        random_error1.append(np.sqrt(mean_squared_error(np.array(a['Sales'].iloc[-2:]), np.array(ypred))))

# %%
#Total Rmse for SES Random Model
print('The Total RMSE of All Customer is for SES RANDOM:-',sum(random_error1)/len(random_error1))
# Out:
# The Total RMSE of All Customer is for SES RANDOM:- 12.231776197614254

# %%
def create_line_plot(x_values, y_values):
    plt.plot(x_values, y_values)
    plt.xlabel('X-axis')
    plt.ylabel('Y-axis')
    plt.title('RMSE Plot')
    plt.show()

# Example data
y_values = []
for i in range(len(Error1)):
    y_values.append(i)

# %%
#SES Error Plot
create_line_plot(y_values,Error1)

# %%
#Random SES Error Plot
create_line_plot(y_values,random_error1)

# %% [markdown]
# # HWES Model (Holt Winter’s Exponential Smoothing)

# %%
from statsmodels.tsa.holtwinters import ExponentialSmoothing as HWES

# %%
Error2 = []

for i in selected_members_20:
    a = Final_data[Final_data['Member_number'] == i]

    model = HWES(a['Sales'].iloc[0:-2],trend='add')
    ypred = model_fit.forecast(2)
    
    Error2.append(np.sqrt(mean_squared_error(np.array(a['Sales'].iloc[-2:]), np.array(ypred))))

# %%
for i in range(len(Error2)):
    print('The RMSE for Forcasted Customer',selected_members_20[i],'is',Error2[i])
# Out:
# The RMSE for Forcasted Customer 4941 is 1.2535712616517463
# The RMSE for Forcasted Customer 2193 is 10.449376503579554
# The RMSE for Forcasted Customer 1997 is 11.193306188075491
# The RMSE for Forcasted Customer 2421 is 18.997368878163194
# The RMSE for Forcasted Customer 1905 is 2.8221107062268356
# The RMSE for Forcasted Customer 4783 is 1.2691695691380982
# The RMSE for Forcasted Customer 3709 is 31.056151478557346
# The RMSE for Forcasted Customer 4272 is 11.912268370102
# The RMSE for Forcasted Customer 2632 is 11.98061245919169
# The RMSE for Forcasted Customer 2270 is 2.0439432775353983
# The RMSE for Forcasted Customer 3811 is 1.5998773735436502
# The RMSE for Forcasted Customer 4875 is 3.501726219055473
# The RMSE for Forcasted Customer 2022 is 8.654246843757203
# The RMSE for Forcasted Customer 4293 is 56.76368715154212
# The RMSE for Forcasted Customer 2560 is 31.633984347194232
# The RMSE for Forcasted Customer 2990 is 18.964883143383755
# The RMSE for Forcasted Customer 3635 is 21.26255057804137
# The RMSE for Forcasted Customer 3915 is 11.663495972732917
# The RMSE for Forcasted Customer 4828 is 11.20478294808395
# The RMSE for Forcasted Customer 3221 is 6.320420719869943
# The RMSE for Forcasted Customer 4338 is 6.437767459551798
# The RMSE for Forcasted Customer 2851 is 15.934458768096759
# The RMSE for Forcasted Customer 2184 is 11.594298532383341
# The RMSE for Forcasted Customer 3361 is 26.726587415665392
# The RMSE for Forcasted Customer 3783 is 15.74147866574767
# The RMSE for Forcasted Customer 3942 is 57.33291160721629
# The RMSE for Forcasted Customer 4187 is 5.418608780529569
# The RMSE for Forcasted Customer 2760 is 26.070424123199828
# The RMSE for Forcasted Customer 2443 is 23.56393068238608
# The RMSE for Forcasted Customer 4494 is 6.26945422312255
# The RMSE for Forcasted Customer 1395 is 4.413362178425006
# The RMSE for Forcasted Customer 2229 is 3.6852523966240116
# The RMSE for Forcasted Customer 3679 is 8.045287468318858
# The RMSE for Forcasted Customer 3495 is 1.7702323569815557
# The RMSE for Forcasted Customer 1410 is 28.29729513979734
# The RMSE for Forcasted Customer 2440 is 82.21459143369589
# The RMSE for Forcasted Customer 2447 is 2.456419788542047
# The RMSE for Forcasted Customer 4217 is 31.759753317565014
# The RMSE for Forcasted Customer 2816 is 9.581377392111364
# The RMSE for Forcasted Customer 3543 is 11.502129956614521
# The RMSE for Forcasted Customer 4524 is 4.4404746342385675
# The RMSE for Forcasted Customer 3180 is 6.035494580003088
# The RMSE for Forcasted Customer 3737 is 21.603377266197896
# The RMSE for Forcasted Customer 1466 is 2.2213478102682958
# The RMSE for Forcasted Customer 3960 is 1.529009972696659
# The RMSE for Forcasted Customer 3246 is 7.779923272700357
# The RMSE for Forcasted Customer 4486 is 4.01539542374414
# The RMSE for Forcasted Customer 3484 is 20.368733680848262
# The RMSE for Forcasted Customer 2799 is 17.710287584006377
# The RMSE for Forcasted Customer 2294 is 12.776128547420917
# The RMSE for Forcasted Customer 3120 is 2.9999421370767623
# The RMSE for Forcasted Customer 3872 is 2.925344231270832
# The RMSE for Forcasted Customer 2394 is 7.213762354433225
# The RMSE for Forcasted Customer 3593 is 6.362728838402288
# The RMSE for Forcasted Customer 4864 is 22.513575794157475
# The RMSE for Forcasted Customer 1737 is 3.849124143862595
# The RMSE for Forcasted Customer 4437 is 15.808010096446843
# The RMSE for Forcasted Customer 2524 is 24.597070734836898
# The RMSE for Forcasted Customer 3090 is 55.30975040703545
# The RMSE for Forcasted Customer 1827 is 13.331410958855312
# The RMSE for Forcasted Customer 4683 is 35.91501768931623
# The RMSE for Forcasted Customer 3752 is 30.341437526146393
# The RMSE for Forcasted Customer 3497 is 5.516618611083665
# The RMSE for Forcasted Customer 4303 is 31.693131944985293
# The RMSE for Forcasted Customer 3164 is 8.252294555771504
# The RMSE for Forcasted Customer 3122 is 3.473720329443397
# The RMSE for Forcasted Customer 1366 is 12.16064870530963
# The RMSE for Forcasted Customer 1225 is 3.568948083238549
# The RMSE for Forcasted Customer 2070 is 5.308119693550784
# The RMSE for Forcasted Customer 1574 is 8.444581800245267
# The RMSE for Forcasted Customer 1379 is 4.729026187930307
# The RMSE for Forcasted Customer 1929 is 4.4164984672787515
# The RMSE for Forcasted Customer 2517 is 9.596514530900114
# The RMSE for Forcasted Customer 2918 is 5.933640391562419
# The RMSE for Forcasted Customer 1780 is 3.046663112247343
# The RMSE for Forcasted Customer 1566 is 38.38951101489777
# The RMSE for Forcasted Customer 2344 is 5.861491354608881
# The RMSE for Forcasted Customer 2868 is 1.6001420772992294
# The RMSE for Forcasted Customer 3289 is 3.5458577319232147
# The RMSE for Forcasted Customer 3465 is 29.164936765106507
# The RMSE for Forcasted Customer 2511 is 2.5921158759382408
# The RMSE for Forcasted Customer 3050 is 17.712183120113778
# The RMSE for Forcasted Customer 4695 is 13.552948552636725
# The RMSE for Forcasted Customer 2625 is 1.7639097583838703
# The RMSE for Forcasted Customer 2492 is 38.43454851303528
# The RMSE for Forcasted Customer 3835 is 19.77584708619262
# The RMSE for Forcasted Customer 4251 is 35.98118591358276
# The RMSE for Forcasted Customer 1793 is 11.270177730210392
# The RMSE for Forcasted Customer 4495 is 5.394839898860965
# The RMSE for Forcasted Customer 1878 is 23.568584919291347
# The RMSE for Forcasted Customer 3251 is 8.128265278816846
# The RMSE for Forcasted Customer 3761 is 13.021410330762912
# The RMSE for Forcasted Customer 2960 is 2.9748638029565027
# The RMSE for Forcasted Customer 4574 is 18.152183662320976
# The RMSE for Forcasted Customer 1275 is 5.4373071311265955
# The RMSE for Forcasted Customer 4877 is 2.3253391333679754
# The RMSE for Forcasted Customer 3957 is 3.5373208331383683
# The RMSE for Forcasted Customer 2234 is 7.480416511964214
# The RMSE for Forcasted Customer 3732 is 1.314699634663985
# The RMSE for Forcasted Customer 4831 is 29.010117021843993
# The RMSE for Forcasted Customer 2855 is 11.923782368738333
# The RMSE for Forcasted Customer 4137 is 5.317213067373169
# The RMSE for Forcasted Customer 3248 is 3.210287432660067
# The RMSE for Forcasted Customer 3266 is 5.300291609126526
# The RMSE for Forcasted Customer 3082 is 49.94443998847009
# The RMSE for Forcasted Customer 2736 is 6.830089830299488
# The RMSE for Forcasted Customer 3046 is 12.967041805743701
# The RMSE for Forcasted Customer 1948 is 21.751160265141753
# The RMSE for Forcasted Customer 4585 is 10.878808014559462
# The RMSE for Forcasted Customer 1353 is 2.9407282772238204
# The RMSE for Forcasted Customer 3247 is 2.842887456732901
# The RMSE for Forcasted Customer 2433 is 2.7409073523522585
# The RMSE for Forcasted Customer 3691 is 26.726587415665392
# The RMSE for Forcasted Customer 1407 is 24.597222899367193
# The RMSE for Forcasted Customer 1595 is 17.751146148965436
# The RMSE for Forcasted Customer 1265 is 11.165735240936842
# The RMSE for Forcasted Customer 2779 is 24.140859217008316
# The RMSE for Forcasted Customer 2512 is 1.5096427954590024
# The RMSE for Forcasted Customer 1098 is 27.426907504165186
# The RMSE for Forcasted Customer 3651 is 13.12043056780357
# The RMSE for Forcasted Customer 4588 is 26.67996582872484
# The RMSE for Forcasted Customer 1998 is 26.0170525860901
# The RMSE for Forcasted Customer 4277 is 17.104094778870273
# The RMSE for Forcasted Customer 2051 is 24.61190515571889
# The RMSE for Forcasted Customer 2271 is 8.888034704796828
# The RMSE for Forcasted Customer 3517 is 7.2738958285036786
# The RMSE for Forcasted Customer 3462 is 10.694643093078327
# The RMSE for Forcasted Customer 1887 is 3.0057164613309775
# The RMSE for Forcasted Customer 1116 is 13.194029929262548
# The RMSE for Forcasted Customer 4376 is 2.743265194418383
# The RMSE for Forcasted Customer 4153 is 7.136439184683071
# The RMSE for Forcasted Customer 4671 is 4.135155757112583
# The RMSE for Forcasted Customer 1087 is 2.68090494880672
# The RMSE for Forcasted Customer 3042 is 15.135176763009783
# The RMSE for Forcasted Customer 4933 is 2.566440501616606
# The RMSE for Forcasted Customer 4656 is 12.849472449983141
# The RMSE for Forcasted Customer 1218 is 13.13552998297624
# The RMSE for Forcasted Customer 1654 is 31.690394187125776
# The RMSE for Forcasted Customer 4753 is 9.237176133910179
# The RMSE for Forcasted Customer 2789 is 2.7403742362653194
# The RMSE for Forcasted Customer 2408 is 30.411440563381586
# The RMSE for Forcasted Customer 2738 is 19.988040050464793
# The RMSE for Forcasted Customer 2706 is 55.24750489677517
# The RMSE for Forcasted Customer 3402 is 3.590668981127683
# The RMSE for Forcasted Customer 1991 is 11.663495972732917
# The RMSE for Forcasted Customer 3830 is 6.548348633087482
# The RMSE for Forcasted Customer 2663 is 10.637287134281351
# The RMSE for Forcasted Customer 2164 is 4.92919373693228
# The RMSE for Forcasted Customer 4364 is 2.1286884276424423
# The RMSE for Forcasted Customer 3862 is 1.663519329604595
# The RMSE for Forcasted Customer 1870 is 4.82197402038195
# The RMSE for Forcasted Customer 1583 is 10.694643093078327
# The RMSE for Forcasted Customer 4190 is 2.8970781555919207
# The RMSE for Forcasted Customer 4679 is 4.107523826800658
# The RMSE for Forcasted Customer 3308 is 13.84812651166135
# The RMSE for Forcasted Customer 1052 is 5.206076709994661
# The RMSE for Forcasted Customer 1004 is 25.178419150285823
# The RMSE for Forcasted Customer 4624 is 38.38951101489777
# The RMSE for Forcasted Customer 2252 is 2.851002246240303
# The RMSE for Forcasted Customer 4297 is 38.39464377944253
# The RMSE for Forcasted Customer 1169 is 40.125007467333646

# %%
#Total Rmse for All Customer
print('The Total RMSE of All Customer is for HWES-',sum(Error2)/len(Error2))
# Out:
# The Total RMSE of All Customer is for HWES- 14.1432866092694

# %%
model_3.append(sum(Error2)/len(Error2))

# %% [markdown]
# ### Random Model RMSE Check to wheather our CLTV model is forecasting usefull

# %%
random_error2 = []
for i in range(162):
    if i ==0:
        continue
    else:
        a = random_values[random_values['Member_number'] == i]
    
        model = HWES(a['Sales'].iloc[0:-2])
        model_fit = model.fit()
    
        #Forcast
        ypred = model_fit.forecast(2)
    
        random_error2.append(np.sqrt(mean_squared_error(np.array(a['Sales'].iloc[-2:]), np.array(ypred))))

# %%
#Total Rmse for HWES Random Model
print('The Total RMSE of All Customer is for HWES RANDOM:-',sum(random_error2)/len(random_error2))
# Out:
# The Total RMSE of All Customer is for HWES RANDOM:- 12.231776197614254

# %%
def create_line_plot(x_values, y_values):
    plt.plot(x_values, y_values)
    plt.xlabel('X-axis')
    plt.ylabel('Y-axis')
    plt.title('RMSE Plot')
    plt.show()

# Example data
y_values = []
for i in range(len(Error2)):
    y_values.append(i)

# %%
#HWES Error Plot
create_line_plot(y_values,Error2)

# %%
#HWES RANDOM Error Plot
create_line_plot(y_values,random_error2)

# %% [markdown]
# # XGBoost Model

# %%
from xgboost import XGBRegressor

# %%
Error4 = []

for i in selected_members_20:
    a = Final_data[Final_data['Member_number'] == i]
    a.reset_index(inplace = True)
    a.rename({'index':'Transactions'},axis = 1,inplace = True)
    
    X_train, X_test, y_train, y_test = train_test_split(a['Transactions'], a['Sales'], test_size=0.10, random_state=100)
    model = XGBRegressor()
    model.fit(X_train,y_train)

    ypred = model.predict(X_test)

    Error4.append(np.sqrt(mean_squared_error(np.array(y_test), np.array(ypred))))

# %%
a.head()
# Out:
#    Transactions  Member_number       Date    itemDescription  Sales  Year
# 0          3787           1169 2014-05-29  finished products  37.31  2014
# 1          3788           1169 2014-01-15   other vegetables   9.20  2014
# 2          3789           1169 2014-01-11               soda   4.20  2014
# 3          3790           1169 2014-04-01             liquor  83.30  2014
# 4          3791           1169 2014-01-25            waffles   8.40  2014

# %%
for i in range(len(Error4)):
    print('The RMSE for Forcasted Customer',selected_members_20[i],'is',Error4[i])
# Out:
# The RMSE for Forcasted Customer 4941 is 15.025671295948323
# The RMSE for Forcasted Customer 2193 is 50.62559162164386
# The RMSE for Forcasted Customer 1997 is 10.007808442981279
# The RMSE for Forcasted Customer 2421 is 20.466368478343757
# The RMSE for Forcasted Customer 1905 is 33.342296918295375
# The RMSE for Forcasted Customer 4783 is 4.600656373693438
# The RMSE for Forcasted Customer 3709 is 16.155274680781886
# The RMSE for Forcasted Customer 4272 is 20.154777495871073
# The RMSE for Forcasted Customer 2632 is 13.639886887448585
# The RMSE for Forcasted Customer 2270 is 15.35856650609194
# The RMSE for Forcasted Customer 3811 is 7.38583616187067
# The RMSE for Forcasted Customer 4875 is 16.81626639163561
# The RMSE for Forcasted Customer 2022 is 55.0047761276238
# The RMSE for Forcasted Customer 4293 is 48.52274500591059
# The RMSE for Forcasted Customer 2560 is 10.370344849520384
# The RMSE for Forcasted Customer 2990 is 9.151540391303142
# The RMSE for Forcasted Customer 3635 is 23.77979181212612
# The RMSE for Forcasted Customer 3915 is 11.590832895916016
# The RMSE for Forcasted Customer 4828 is 18.068654345417098
# The RMSE for Forcasted Customer 3221 is 67.73577601175376
# The RMSE for Forcasted Customer 4338 is 6.295422375190793
# The RMSE for Forcasted Customer 2851 is 6.985950153068566
# The RMSE for Forcasted Customer 2184 is 24.114125429592335
# The RMSE for Forcasted Customer 3361 is 33.15705682767585
# The RMSE for Forcasted Customer 3783 is 12.907957738545376
# The RMSE for Forcasted Customer 3942 is 8.901533167722274
# The RMSE for Forcasted Customer 4187 is 17.31627103805109
# The RMSE for Forcasted Customer 2760 is 18.821375741387566
# The RMSE for Forcasted Customer 2443 is 39.84444290613515
# The RMSE for Forcasted Customer 4494 is 6.538662467894643
# The RMSE for Forcasted Customer 1395 is 24.639816500978974
# The RMSE for Forcasted Customer 2229 is 5.491298639490785
# The RMSE for Forcasted Customer 3679 is 6.34313441228647
# The RMSE for Forcasted Customer 3495 is 2.6311646033571234
# The RMSE for Forcasted Customer 1410 is 43.414583785517756
# The RMSE for Forcasted Customer 2440 is 27.431194132396424
# The RMSE for Forcasted Customer 2447 is 13.41843177747435
# The RMSE for Forcasted Customer 4217 is 9.437194100836544
# The RMSE for Forcasted Customer 2816 is 8.101250118076583
# The RMSE for Forcasted Customer 3543 is 19.336479177687007
# The RMSE for Forcasted Customer 4524 is 8.483821545917909
# The RMSE for Forcasted Customer 3180 is 11.130812961961228
# The RMSE for Forcasted Customer 3737 is 32.238362800061125
# The RMSE for Forcasted Customer 1466 is 19.373856755544047
# The RMSE for Forcasted Customer 3960 is 10.936273948708747
# The RMSE for Forcasted Customer 3246 is 13.812233455680273
# The RMSE for Forcasted Customer 4486 is 3.83111968535315
# The RMSE for Forcasted Customer 3484 is 26.62399422493978
# The RMSE for Forcasted Customer 2799 is 27.574782347997346
# The RMSE for Forcasted Customer 2294 is 9.69532690968993
# The RMSE for Forcasted Customer 3120 is 27.470547248487794
# The RMSE for Forcasted Customer 3872 is 18.255259164617854
# The RMSE for Forcasted Customer 2394 is 11.21901757790912
# The RMSE for Forcasted Customer 3593 is 9.231620025423254
# The RMSE for Forcasted Customer 4864 is 13.172825483978977
# The RMSE for Forcasted Customer 1737 is 9.739300790890526
# The RMSE for Forcasted Customer 4437 is 19.538139622055365
# The RMSE for Forcasted Customer 2524 is 20.486925111687448
# The RMSE for Forcasted Customer 3090 is 49.50902547913901
# The RMSE for Forcasted Customer 1827 is 35.1639764037541
# The RMSE for Forcasted Customer 4683 is 52.498371029599426
# The RMSE for Forcasted Customer 3752 is 16.745307880105255
# The RMSE for Forcasted Customer 3497 is 6.12623729867218
# The RMSE for Forcasted Customer 4303 is 15.99774851590429
# The RMSE for Forcasted Customer 3164 is 10.846703048083423
# The RMSE for Forcasted Customer 3122 is 6.123922227183221
# The RMSE for Forcasted Customer 1366 is 29.19892936384388
# The RMSE for Forcasted Customer 1225 is 14.150445125363154
# The RMSE for Forcasted Customer 2070 is 28.949452658272026
# The RMSE for Forcasted Customer 1574 is 5.4460663604623205
# The RMSE for Forcasted Customer 1379 is 9.577393988729511
# The RMSE for Forcasted Customer 1929 is 10.186016321781002
# The RMSE for Forcasted Customer 2517 is 5.681864028465977
# The RMSE for Forcasted Customer 2918 is 15.566408734394338
# The RMSE for Forcasted Customer 1780 is 2.9594856855095175
# The RMSE for Forcasted Customer 1566 is 56.48829188551012
# The RMSE for Forcasted Customer 2344 is 11.839418542817722
# The RMSE for Forcasted Customer 2868 is 14.169718249240848
# The RMSE for Forcasted Customer 3289 is 6.84548775553716
# The RMSE for Forcasted Customer 3465 is 25.213042680607142
# The RMSE for Forcasted Customer 2511 is 7.122646867125853
# The RMSE for Forcasted Customer 3050 is 7.988332356601529
# The RMSE for Forcasted Customer 4695 is 37.973028963780656
# The RMSE for Forcasted Customer 2625 is 12.873421384774934
# The RMSE for Forcasted Customer 2492 is 32.22838960670261
# The RMSE for Forcasted Customer 3835 is 14.736269819522441
# The RMSE for Forcasted Customer 4251 is 40.717159624190614
# The RMSE for Forcasted Customer 1793 is 44.56142664389392
# The RMSE for Forcasted Customer 4495 is 15.336448581350615
# The RMSE for Forcasted Customer 1878 is 18.675594924643956
# The RMSE for Forcasted Customer 3251 is 4.497740236157384
# The RMSE for Forcasted Customer 3761 is 24.32344256843095
# The RMSE for Forcasted Customer 2960 is 23.035177879078205
# The RMSE for Forcasted Customer 4574 is 23.761362252615182
# The RMSE for Forcasted Customer 1275 is 19.13110746410803
# The RMSE for Forcasted Customer 4877 is 9.40405884104276
# The RMSE for Forcasted Customer 3957 is 14.84705518955766
# The RMSE for Forcasted Customer 2234 is 8.70153494216051
# The RMSE for Forcasted Customer 3732 is 39.75403400790896
# The RMSE for Forcasted Customer 4831 is 5.673679633541071
# The RMSE for Forcasted Customer 2855 is 9.013335421723939
# The RMSE for Forcasted Customer 4137 is 15.482016212433926
# The RMSE for Forcasted Customer 3248 is 9.854235482170672
# The RMSE for Forcasted Customer 3266 is 35.45112928009366
# The RMSE for Forcasted Customer 3082 is 8.001957645126149
# The RMSE for Forcasted Customer 2736 is 14.163236786711005
# The RMSE for Forcasted Customer 3046 is 8.88092251183756
# The RMSE for Forcasted Customer 1948 is 7.446401305806181
# The RMSE for Forcasted Customer 4585 is 15.42595208533776
# The RMSE for Forcasted Customer 1353 is 6.499870770231184
# The RMSE for Forcasted Customer 3247 is 12.294642092622844
# The RMSE for Forcasted Customer 2433 is 32.26428743057677
# The RMSE for Forcasted Customer 3691 is 31.549569056279523
# The RMSE for Forcasted Customer 1407 is 16.13845765274664
# The RMSE for Forcasted Customer 1595 is 34.663817692839466
# The RMSE for Forcasted Customer 1265 is 12.42297338726226
# The RMSE for Forcasted Customer 2779 is 9.519828318701629
# The RMSE for Forcasted Customer 2512 is 44.15622363573723
# The RMSE for Forcasted Customer 1098 is 8.997045460801557
# The RMSE for Forcasted Customer 3651 is 17.942514809168365
# The RMSE for Forcasted Customer 4588 is 26.67246143586437
# The RMSE for Forcasted Customer 1998 is 30.5422189301395
# The RMSE for Forcasted Customer 4277 is 10.454545726015512
# The RMSE for Forcasted Customer 2051 is 31.858220740827104
# The RMSE for Forcasted Customer 2271 is 23.028503692260013
# The RMSE for Forcasted Customer 3517 is 47.35773225844155
# The RMSE for Forcasted Customer 3462 is 9.824479627023091
# The RMSE for Forcasted Customer 1887 is 11.039397055043564
# The RMSE for Forcasted Customer 1116 is 12.7557814598436
# The RMSE for Forcasted Customer 4376 is 10.468554682996327
# The RMSE for Forcasted Customer 4153 is 27.373199789220145
# The RMSE for Forcasted Customer 4671 is 34.293125262768676
# The RMSE for Forcasted Customer 1087 is 26.623389211371762
# The RMSE for Forcasted Customer 3042 is 9.53059033713226
# The RMSE for Forcasted Customer 4933 is 6.235695384742481
# The RMSE for Forcasted Customer 4656 is 28.806088467766834
# The RMSE for Forcasted Customer 1218 is 11.150598328785922
# The RMSE for Forcasted Customer 1654 is 48.861172317174464
# The RMSE for Forcasted Customer 4753 is 9.29371891359875
# The RMSE for Forcasted Customer 2789 is 7.383169983725913
# The RMSE for Forcasted Customer 2408 is 43.595916618026244
# The RMSE for Forcasted Customer 2738 is 18.66396794548135
# The RMSE for Forcasted Customer 2706 is 8.849299846689568
# The RMSE for Forcasted Customer 3402 is 13.860324910502028
# The RMSE for Forcasted Customer 1991 is 8.85675513548306
# The RMSE for Forcasted Customer 3830 is 3.9142572781049876
# The RMSE for Forcasted Customer 2663 is 25.559322683955912
# The RMSE for Forcasted Customer 2164 is 13.587204422896402
# The RMSE for Forcasted Customer 4364 is 3.6925946619696695
# The RMSE for Forcasted Customer 3862 is 4.850255374053361
# The RMSE for Forcasted Customer 1870 is 8.830309785360322
# The RMSE for Forcasted Customer 1583 is 11.615599321556317
# The RMSE for Forcasted Customer 4190 is 8.561597495189265
# The RMSE for Forcasted Customer 4679 is 46.035663914381445
# The RMSE for Forcasted Customer 3308 is 17.827068127063193
# The RMSE for Forcasted Customer 1052 is 18.24806085511394
# The RMSE for Forcasted Customer 1004 is 17.73877299852385
# The RMSE for Forcasted Customer 4624 is 31.251667411572083
# The RMSE for Forcasted Customer 2252 is 16.93082764315231
# The RMSE for Forcasted Customer 4297 is 14.459848723185646
# The RMSE for Forcasted Customer 1169 is 40.53867102676578

# %%
#Total Rmse for XGBoost Random Model
print('The Total RMSE of All Customer is for XGBoost:-',sum(Error4)/len(Error4))
# Out:
# The Total RMSE of All Customer is for XGBoost:- 19.14011987155644

# %%
model_4.append(sum(Error4)/len(Error4))

# %% [markdown]
# ### Random Model RMSE Check to wheather our CLTV model is forecasting usefull

# %%
random_error4 = []
for i in range(162):
    if i ==0:
        continue
    else:
        a = random_values[random_values['Member_number'] == i]
        a.reset_index(inplace = True)
        a.rename({'index':'Transactions'},axis = 1,inplace = True)
    
        X_train, X_test, y_train, y_test = train_test_split(a['Transactions'], a['Sales'], test_size=0.10,random_state=100)
        model = XGBRegressor()
        model.fit(X_train,y_train)
    
        #Forcast
        ypred = model.predict(X_test)
    
        random_error4.append(np.sqrt(mean_squared_error(np.array(y_test), np.array(ypred))))

# %%
#Total Rmse for XGBOOST Random Model
print('The Total RMSE of All Customer is for XGBOOST RANDOM:-',sum(random_error4)/len(random_error4))
# Out:
# The Total RMSE of All Customer is for XGBOOST RANDOM:- 15.894570455119101

# %%
def create_line_plot(x_values, y_values):
    plt.plot(x_values, y_values)
    plt.xlabel('X-axis')
    plt.ylabel('Y-axis')
    plt.title('RMSE Plot')
    plt.show()

# Example data
y_values = []
for i in range(len(Error4)):
    y_values.append(i)

# %%
#XGBOOST Error Plot
create_line_plot(y_values,Error4)

# %%
#XGBOOST RANDOM Error Plot
create_line_plot(y_values,random_error4)

# %%
Final_data.Sales.shape
# Out:
# (3808,)

# %% [markdown]
# # Students Paired T-test

# %% [raw]
# Hypothesis:- There are no significant difference between the "Random" Sales generated compared to the "Original" Sales Data.

# %% [raw]
# To Accept or Reject the Hypothesis We use Students paired T-Test to compare the means,Standard Deviation of between two groups
# to calculate the critical value "T" to check with the Probability of "P" = 0.05 in the T-table to accept or reject the Null Hypothesis
#
#                                                        p=0.05
# Accept the Null Hypothesis<------------------------Critical Value------------------------------>Reject the Null Hypothesis

# %% [raw]
# Paired Formula:- t = (d*(root(n))/sd
#
# where d = mean of the differences
# n = number of samples in the dataset
# sd = standard Deviation of the differences

# %%
A = random_values.Sales
B = Final_data.Sales.iloc[0:3800]
Differences = A-B

# %%
Differences
# Out:
# 0       15.606588
# 1       39.246244
# 2       63.144563
# 3      -59.070305
# 4      -18.276854
#           ...
# 3795     5.725182
# 3796     8.027726
# 3797   -22.121719
# 3798     6.863056
# 3799    -0.537529
# Name: Sales, Length: 3800, dtype: float64

# %%
N = len(Differences)
Dmean = sum(Differences)/len(Differences)
SD = np.std(Differences)

#Degrees of Freedom to get the value from T-table
DF = N-1

# %%
#number of Samples
N
# Out:
# 3800

# %%
#Differences Mean
Dmean
# Out:
# -0.1986041872513202

# %%
#Standard Deviation
SD
# Out:
# 21.41835882532046

# %%
#Degree of Freedom
DF
# Out:
# 3799

# %%
#T-Value
T = (Dmean*math.sqrt(N))/SD

# %%
#Ignore the (-) minus
T
# Out:
# -0.5716023542816864

# %% [raw]
# The Cirtical Value for "Degree of Freedom" (3219) for "Significant Level" (0.05) is (1.960) is "T-table"
#
# Therefore
#
#                                                        1.960
# Accept the Null Hypothesis<------------------------Critical Value------------------------------>Reject the Null Hypothesis
#                                     0.28
#
# Since the T-value (0.13) is less then the Critical Value (1.960) so We will accept the Null Hypothesis. There is no Significant difference between the "Random Sales" Generated and the "Original Sales" dataset

# %% [markdown]
# # T-Test Package

# %%
import researchpy as rp
import scipy.stats as stats

# %%
#Random Generated
A
# Out:
# 0       22.806588
# 1       46.446244
# 2       71.694563
# 3       10.929695
# 4        0.763146
#           ...
# 3795     8.035182
# 3796    11.807726
# 3797     3.798281
# 3798    15.903056
# 3799    19.142471
# Name: Sales, Length: 3800, dtype: float64

# %%
#Original
B
# Out:
# 0        7.20
# 1        7.20
# 2        8.55
# 3       70.00
# 4       19.04
#         ...
# 3795     2.31
# 3796     3.78
# 3797    25.92
# 3798     9.04
# 3799    19.68
# Name: Sales, Length: 3800, dtype: float64

# %% [markdown]
# # T-TEST USING RESEARCHPY

# %%
rp.ttest(group1=A , group2=B)
# Out:
# (   Variable       N       Mean         SD        SE  95% Conf.   Interval
#  0     Sales  3800.0  15.649877  15.252295  0.247425  15.164779  16.134976
#  1     Sales  3800.0  15.848482  15.162649  0.245971  15.366234  16.330729
#  2  combined  7600.0  15.749179  15.206862  0.174435  15.407239  16.091120,
#                Independent t-test    results
#  0  Difference (Sales - Sales) =     -0.1986
#  1          Degrees of freedom =   7598.0000
#  2                           t =     -0.5693
#  3       Two side test p value =      0.5692
#  4      Difference < 0 p value =      0.2846
#  5      Difference > 0 p value =      0.7154
#  6                   Cohen's d =     -0.0131
#  7                   Hedge's g =     -0.0131
#  8              Glass's delta1 =     -0.0130
#  9            Point-Biserial r =     -0.0065)

# %% [markdown]
# # T-TEST USING SCIPY.STATS

# %%
stats.ttest_ind(A,B)
# Out:
# Ttest_indResult(statistic=-0.5692542460897733, pvalue=0.5692004394705177)

# %% [markdown]
# # Anova Test

# %% [raw]
# Define Your Hypotheses:
#
# Null Hypothesis (H0): There is no significant difference in the performance of the models.
# Alternative Hypothesis (Ha): There is a significant difference in the performance of the models.
# Collect and Prepare Data:
#
# Ensure you have the performance metric (e.g., accuracy, F1 score, RMSE) for each model on the same dataset or set of datasets. This data should be numeric and normally distributed for ANOVA to be appropriate.
# Calculate Model Performance Metrics:
#
# Calculate the performance metric (e.g., mean squared error) for each model on the same dataset(s). You'll have one performance metric for each model.
# Perform ANOVA:
#
# Use a statistical software package (e.g., Python's scipy.stats.f_oneway, R's aov function) to perform the ANOVA test on your data.
# The ANOVA test will produce an F-statistic and a p-value. The F-statistic measures the ratio of the variance between groups to the variance within groups. The p-value indicates whether the differences in means are statistically significant.
# Interpret the Results:
#
# If the p-value is less than your chosen significance level (e.g., 0.05), you can reject the null hypothesis and conclude that there is a statistically significant difference in the performance of the models.
# If the p-value is greater than your chosen significance level, you fail to reject the null hypothesis, indicating that there is no significant difference in the performance of the models.
# Post hoc Tests (Optional):
#
# If the ANOVA test indicates a significant difference, you can perform post hoc tests to determine which specific models differ from each other. Common post hoc tests include Tukey's HSD (Honestly Significant Difference) test and Bonferroni correction.
# Visualize the Results (Optional):
#
# You can create plots or graphs to visualize the differences in performance between models, which can be helpful for interpretation and presentation.

# %%
import scipy.stats as stats

# Perform the ANOVA test
f_statistic, p_value = stats.f_oneway(model_1,model_2,model_3,model_4)

print("The P-value for four different models by comparing the MSE and mesure the ratio of variance:- ",p_value)
# Set your significance level (alpha)
alpha = 0.05

# Interpret the results
if p_value < alpha:
    print("Reject the null hypothesis: There is a significant difference in model performance.")
else:
    print("Fail to reject the null hypothesis: There is no significant difference in model performance.")

# Optionally, you can perform post hoc tests if the ANOVA is significant to identify specific differences between groups.
# Out:
# The P-value for four different models by comparing the MSE and mesure the ratio of variance:-  nan
# Fail to reject the null hypothesis: There is no significant difference in model performance.

# %% [markdown]
# # Super Market Recommendation

# %%
New_data.head()
# Out:
#    Member_number       Date   itemDescription  Sales  Year
# 0           1808 2015-07-21    tropical fruit   7.95  2015
# 1           2552 2015-05-01        whole milk  25.92  2015
# 2           2300 2015-09-19         pip fruit   8.96  2015
# 3           1187 2015-12-12  other vegetables  32.20  2015
# 4           3037 2015-01-02        whole milk  12.96  2015

# %%
recommend = New_data.set_index(['Date'])

# %%
recommend.index = pd.to_datetime(recommend.index)

# %%
recommend.head()
# Out:
#             Member_number   itemDescription  Sales  Year
# Date
# 2015-07-21           1808    tropical fruit   7.95  2015
# 2015-05-01           2552        whole milk  25.92  2015
# 2015-09-19           2300         pip fruit   8.96  2015
# 2015-12-12           1187  other vegetables  32.20  2015
# 2015-01-02           3037        whole milk  12.96  2015

# %%
total_items = len(recommend)
total_days = len(np.unique(recommend.index.date))
total_months = len(np.unique(recommend.index.month))
average_items = total_items / total_days
unique_items = recommend.itemDescription.unique().size

print("There are {} unique items sold ".format(unique_items))
print("Total {} items sold in {} days throughout {} months".format(total_items, total_days, total_months))
print("With an average of {} items sold daily".format(average_items))
# Out:
# There are 167 unique items sold
# Total 38765 items sold in 728 days throughout 12 months
# With an average of 53.24862637362637 items sold daily

# %%
recommend.resample("D")['itemDescription'].count().plot(figsize=(12,5), grid=True, title="Number of total Items Sold by Date").set(xlabel="Date", ylabel="Number of total Items Sold")
# Out:
# [Text(0.5, 0, 'Date'), Text(0, 0.5, 'Number of total Items Sold')]

# %%
recommend.resample("M")['itemDescription'].count().plot(figsize=(12,5), grid=True, title="Number by Items Total Sold by Month").set(xlabel="Date", ylabel="Number of Total Items Sold")
# Out:
# [Text(0.5, 0, 'Date'), Text(0, 0.5, 'Number of Total Items Sold')]

# %%
recommend["Weekday"] = recommend.index.weekday + 1
recommend["Hour"] =recommend.index.hour

# %%
import plotly.express as px
from mlxtend.preprocessing import TransactionEncoder

TE = TransactionEncoder()

# %%
items_transactions = [a[1]['itemDescription'].tolist() for a in list(recommend.groupby(['Member_number','Date']))]

# %%
print("all items transactions are:-",items_transactions)
# Out:
# all items transactions are:- [['whole milk', 'pastry', 'salty snack'], ['sausage', 'whole milk', 'semi-finished bread', 'yogurt'], ['soda', 'pickled vegetables'], ['canned beer', 'misc. beverages'], ['sausage', 'hygiene articles'], ['sausage', 'whole milk', 'rolls/buns'], ['whole milk', 'soda'], ['frankfurter', 'soda', 'whipped/sour cream'], ['frankfurter', 'curd'], ['beef', 'white bread'], ['butter', 'whole milk'], ['frozen vegetables', 'other vegetables'], ['tropical fruit', 'sugar'], ['butter milk', 'specialty chocolate'], ['frozen meals', 'dental care'], ['rolls/buns', 'rolls/buns'], ['root vegetables', 'detergent'], ['sausage', 'rolls/buns'], ['dish cleaner', 'cling film/bags'], ['canned beer', 'frozen fish'], ['pip fruit', 'whole milk', 'tropical fruit'], ['root vegetables', 'whole milk', 'pastry'], ['rolls/buns', 'red/blush wine', 'chocolate'], ['other vegetables', 'shopping bags'], ['whole milk', 'chocolate', 'packaged fruit/vegetables', 'rolls/buns'], ['other vegetables', 'hygiene articles'], ['whipped/sour cream', 'margarine'], ['rolls/buns', 'rolls/buns'], ['bottled water', 'softener', 'rolls/buns'], ['whole milk', 'rice'], ['shopping bags', 'skin care'], ['whole milk', 'frankfurter', 'chicken', 'frankfurter', 'flour', 'chocolate', 'bottled beer', 'rolls/buns'], ['hamburger meat', 'liquor (appetizer)', 'liver loaf', 'dessert'], ['tropical fruit', 'soda', 'yogurt', 'root vegetables', 'yogurt', 'domestic eggs', 'white wine', 'photo/film'], ['canned fish', 'cocoa drinks'], ['herbs', 'yogurt', 'newspapers'], ['tropical fruit', 'yogurt'], ['pastry', 'ketchup'], ['pip fruit', 'coffee', 'UHT-milk'], ['bottled water', 'specialty bar'], ['frankfurter', 'bottled water'], ['kitchen towels', 'sliced cheese'], ['pip fruit', 'candles', 'rolls/buns'], ['curd cheese', 'pastry'], ['citrus fruit', 'candy', 'bottled water', 'rolls/buns'], ['whole milk', 'frankfurter', 'candles', 'grapes', 'herbs', 'other vegetables', 'yogurt'], ['frozen vegetables', 'brown bread'], ['frankfurter', 'yogurt'], ['processed cheese', 'whole milk'], ['tropical fruit', 'root vegetables', 'rolls/buns', 'onions', 'shopping bags'], ['hard cheese', 'napkins', 'bottled water'], ['whole milk', 'candy'], ['tropical fruit', 'frozen vegetables'], ['mustard', 'whipped/sour cream'], ['other vegetables', 'mustard'], ['root vegetables', 'mayonnaise'], ['frozen meals', 'whole milk'], ['white bread', 'meat', 'domestic eggs', 'roll products '], ['hamburger meat', 'butter milk'], ['whole milk', 'rolls/buns'], ['whole milk', 'sausage', 'bottled beer', 'yogurt'], ['canned beer', 'cookware'], ['fruit/vegetable juice', 'rolls/buns', 'chocolate'], ['salty snack', 'beef'], ['citrus fruit', 'whole milk'], ['soft cheese', 'pip fruit'], ['UHT-milk', 'bottled beer'], ['chicken', 'red/blush wine'], ['rolls/buns', 'frankfurter', 'oil', 'pip fruit', 'mayonnaise'], ['other vegetables', 'root vegetables'], ['yogurt', 'beef'], ['brown bread', 'pet care'], ['other vegetables', 'rolls/buns'], ['soda', 'dessert', 'shopping bags'], ['curd', 'long life bakery product'], ['beverages', 'domestic eggs'], ['berries', 'cake bar'], ['butter milk', 'root vegetables'], ['hamburger meat', 'red/blush wine'], ['frozen meals', 'butter', 'newspapers', 'yogurt'], ['canned beer', 'shopping bags'], ['canned beer', 'spices', 'rolls/buns', 'frozen fish'], ['sliced cheese', 'butter'], ['rolls/buns', 'baking powder'], ['liquor', 'curd', 'yogurt', 'tropical fruit'], ['beef', 'napkins'], ['whole milk', 'whipped/sour cream'], ['sausage', 'fruit/vegetable juice'], ['chicken', 'frozen meals'], ['male cosmetics', 'curd'], ['domestic eggs', 'soda'], ['sausage', 'whipped/sour cream', 'specialty bar'], ['whipped/sour cream', 'root vegetables', 'rolls/buns', 'packaged fruit/vegetables'], ['white bread', 'bottled beer', 'yogurt', 'berries'], ['fish', 'root vegetables', 'tropical fruit', 'other vegetables'], ['coffee', 'shopping bags'], ['ham', 'cream cheese '], ['canned beer', 'UHT-milk'], ['root vegetables', 'long life baker ...

# %%
transformed = TE.fit(items_transactions).transform(items_transactions)

# %%
all_transactions = pd.DataFrame(transformed , columns=TE.columns_)
pf = all_transactions.describe()

# %%
pf
# Out:
#        Instant food products UHT-milk abrasive cleaner artif. sweetener  \
# count                  14963    14963            14963            14963
# unique                     2        2                2                2
# top                    False    False            False            False
# freq                   14903    14643            14941            14934
#
#        baby cosmetics   bags baking powder bathroom cleaner   beef berries  \
# count           14963  14963         14963            14963  14963   14963
# unique              2      2             2                2      2       2
# top             False  False         False            False  False   False
# freq            14960  14959         14842            14946  14455   14637
#
#         ... turkey vinegar waffles whipped/sour cream whisky white bread  \
# count   ...  14963   14963   14963              14963  14963       14963
# unique  ...      2       2       2                  2      2           2
# top     ...  False   False   False              False  False       False
# freq    ...  14883   14912   14686              14309  14955       14604
#
#        white wine whole milk yogurt zwieback
# count       14963      14963  14963    14963
# unique          2          2      2        2
# top         False      False  False    False
# freq        14788      12600  13678    14903
#
# [4 rows x 167 columns]

# %%
#REFERENCED FROM KAGGLE

f = pf.iloc[0]-pf.iloc[3]
a = f.tolist()
b = list(f.index)
item = pd.DataFrame([[a[r],b[r]]for r in range(len(a))], columns=['Count','Item'])
item = item.sort_values(['Count'], ascending=False).head(50)

# %%
item
# Out:
#      Count                      Item
# 164   2363                whole milk
# 102   1827          other vegetables
# 122   1646                rolls/buns
# 138   1453                      soda
# 165   1285                    yogurt
# 123   1041           root vegetables
# 156   1014            tropical fruit
# 12     908             bottled water
# 130    903                   sausage
# 30     795              citrus fruit
# 105    774                    pastry
# 109    734                 pip fruit
# 133    712             shopping bags
# 20     702               canned beer
# 11     678              bottled beer
# 160    654        whipped/sour cream
# 95     582                newspapers
# 56     565               frankfurter
# 14     563               brown bread
# 111    555                      pork
# 49     555             domestic eggs
# 15     527                    butter
# 64     509     fruit/vegetable juice
# 8      508                      beef
# 40     504                      curd
# 88     482                 margarine
# 34     473                    coffee
# 63     419         frozen vegetables
# 27     417                   chicken
# 162    359               white bread
# 39     354             cream cheese
# 28     353                 chocolate
# 44     353                   dessert
# 94     331                   napkins
# 68     327            hamburger meat
# 9      326                   berries
# 1      320                  UHT-milk
# 99     303                    onions
# 128    281               salty snack
# 159    277                   waffles
# 85     268  long life bakery product
# 150    265                     sugar
# 16     263               butter milk
# 67     256                       ham
# 90     252                      meat
# 61     251              frozen meals
# 10     248                 beverages
# 145    239       specialty chocolate
# 92     236           misc. beverages
# 74     227                 ice cream

# %%
from mlxtend.frequent_patterns import apriori, association_rules
import matplotlib.pyplot as plt

# %%
all_transactions.rename(columns=lambda x: x.title(), inplace=True)

# %%
all_transactions
# Out:
#        Instant Food Products  Uht-Milk  Abrasive Cleaner  Artif. Sweetener  \
# 0                      False     False             False             False
# 1                      False     False             False             False
# 2                      False     False             False             False
# 3                      False     False             False             False
# 4                      False     False             False             False
# ...                      ...       ...               ...               ...
# 14958                  False     False             False             False
# 14959                  False     False             False             False
# 14960                  False     False             False             False
# 14961                  False     False             False             False
# 14962                  False     False             False             False
#
#        Baby Cosmetics   Bags  Baking Powder  Bathroom Cleaner   Beef  Berries  \
# 0               False  False          False             False  False    False
# 1               False  False          False             False  False    False
# 2               False  False          False             False  False    False
# 3               False  False          False             False  False    False
# 4               False  False          False             False  False    False
# ...               ...    ...            ...               ...    ...      ...
# 14958           False  False          False             False  False    False
# 14959           False  False          False             False  False    False
# 14960           False  False          False             False  False    False
# 14961           False  False          False             False  False    False
# 14962           False  False          False             False  False    False
#
#        ...  Turkey  Vinegar  Waffles  Whipped/Sour Cream  Whisky  White Bread  \
# 0      ...   False    False    False               False   False        False
# 1      ...   False    False    False               False   False        False
# 2      ...   False    False    False               False   False        False
# 3      ...   False    False    False               False   False        False
# 4      ...   False    False    False               False   False        False
# ...    ...     ...      ...      ...                 ...     ...          ...
# 14958  ...   False    False    False                True   False        False
# 14959  ...   False    False    False               False   False        False
# 14960  ...   False    False    False               False   False        False
# 14961  ...   False    False    False               False   False        False
# 14962  ...   False    False    False               False   False        False
#
#        White Wine  Whole Milk  Yogurt  Zwieback
# 0           False        True   False     False
# 1           False        True    True     False
# 2           False       False   False     False
# 3           False       False   False     False
# 4           False       False   False     False
# ...           ...         ...     ...       ...
# 14958       False       False   False     False
# 14959       False       False   False     False
# 14960       False       False   False     False
# 14961       False       False   False     False
# 14962       False       False   False     False
#
# [14963 rows x 167 columns]

# %% [raw]
# Support measures the frequency or occurrence of a specific itemset (a combination of items) in the dataset. It tells you how often a particular itemset appears in the dataset. The support of an itemset is calculated as the number of transactions containing that itemset divided by the total number of transactions in the dataset.

# %%
frequqncy_of_items = apriori(all_transactions, min_support=0.001, use_colnames=True, verbose=1)
frequqncy_of_items
# Out:
# Processing 28 combinations | Sampling itemset size 4e 3
#       support                           itemsets
# 0    0.004010            (Instant Food Products)
# 1    0.021386                         (Uht-Milk)
# 2    0.001470                 (Abrasive Cleaner)
# 3    0.001938                 (Artif. Sweetener)
# 4    0.008087                    (Baking Powder)
# ..        ...                                ...
# 745  0.001136  (Rolls/Buns, Whole Milk, Sausage)
# 746  0.001002     (Rolls/Buns, Whole Milk, Soda)
# 747  0.001337   (Rolls/Buns, Whole Milk, Yogurt)
# 748  0.001069        (Soda, Whole Milk, Sausage)
# 749  0.001470      (Whole Milk, Yogurt, Sausage)
#
# [750 rows x 2 columns]

# %%
frequqncy_of_items['length'] = frequqncy_of_items['itemsets'].apply(lambda x: len(x))

# %%
frequqncy_of_items
# Out:
#       support                           itemsets  length
# 0    0.004010            (Instant Food Products)       1
# 1    0.021386                         (Uht-Milk)       1
# 2    0.001470                 (Abrasive Cleaner)       1
# 3    0.001938                 (Artif. Sweetener)       1
# 4    0.008087                    (Baking Powder)       1
# ..        ...                                ...     ...
# 745  0.001136  (Rolls/Buns, Whole Milk, Sausage)       3
# 746  0.001002     (Rolls/Buns, Whole Milk, Soda)       3
# 747  0.001337   (Rolls/Buns, Whole Milk, Yogurt)       3
# 748  0.001069        (Soda, Whole Milk, Sausage)       3
# 749  0.001470      (Whole Milk, Yogurt, Sausage)       3
#
# [750 rows x 3 columns]

# %% [raw]
# Confidence measures the strength of association between two itemsets, typically in the form of a rule: "If itemset X is present, then itemset Y is also present." It quantifies the probability that itemset Y will be found in a transaction when itemset X is already present in that transaction

# %%
association = association_rules(frequqncy_of_items, metric="confidence", min_threshold=0.001)

# %%
association.head()
# Out:
#           antecedents         consequents  antecedent support  \
# 0          (Uht-Milk)     (Bottled Water)            0.021386
# 1     (Bottled Water)          (Uht-Milk)            0.060683
# 2  (Other Vegetables)          (Uht-Milk)            0.122101
# 3          (Uht-Milk)  (Other Vegetables)            0.021386
# 4        (Rolls/Buns)          (Uht-Milk)            0.110005
#
#    consequent support   support  confidence      lift  leverage  conviction  \
# 0            0.060683  0.001069    0.050000  0.823954 -0.000228    0.988755
# 1            0.021386  0.001069    0.017621  0.823954 -0.000228    0.996168
# 2            0.021386  0.002139    0.017515  0.818993 -0.000473    0.996060
# 3            0.122101  0.002139    0.100000  0.818993 -0.000473    0.975443
# 4            0.021386  0.001804    0.016403  0.767013 -0.000548    0.994934
#
#    zhangs_metric
# 0      -0.179204
# 1      -0.185312
# 2      -0.201119
# 3      -0.184234
# 4      -0.254457

# %% [markdown]
# # Customer Segmentation and Migration

# %%
from matplotlib.sankey import Sankey

# %%
New_data.head()
# Out:
#    Member_number       Date   itemDescription  Sales  Year
# 0           1808 2015-07-21    tropical fruit   7.95  2015
# 1           2552 2015-05-01        whole milk  25.92  2015
# 2           2300 2015-09-19         pip fruit   8.96  2015
# 3           1187 2015-12-12  other vegetables  32.20  2015
# 4           3037 2015-01-02        whole milk  12.96  2015

# %%
segment = New_data.copy()

# %%
segment.head()
# Out:
#    Member_number       Date   itemDescription  Sales  Year
# 0           1808 2015-07-21    tropical fruit   7.95  2015
# 1           2552 2015-05-01        whole milk  25.92  2015
# 2           2300 2015-09-19         pip fruit   8.96  2015
# 3           1187 2015-12-12  other vegetables  32.20  2015
# 4           3037 2015-01-02        whole milk  12.96  2015

# %%
print("Total Sales:-",sum(segment['Sales']))
# Out:
# Total Sales:- 612958.3800000382

# %%
print("Unique Years:-",segment['Year'].unique())
# Out:
# Unique Years:- [2015 2014]

# %%
pd.DataFrame(segment[segment['Year'] == 2014][['Member_number','Sales','Year']].groupby(['Member_number','Year'])['Sales'].sum()).reset_index()
# Out:
#       Member_number  Year   Sales
# 0              1000  2014   43.23
# 1              1001  2014   60.30
# 2              1002  2014   88.78
# 3              1003  2014   45.73
# 4              1004  2014  275.55
# ...             ...   ...     ...
# 3438           4993  2014  110.07
# 3439           4995  2014   52.75
# 3440           4997  2014   20.04
# 3441           4999  2014   26.19
# 3442           5000  2014   60.47
#
# [3443 rows x 3 columns]

# %%
#Seperating the customers into each individual YEAR so i can get the customer migration

cluster2014 = pd.DataFrame(segment[segment['Year'] == 2014][['Member_number','Sales','Year']].groupby(['Member_number','Year'])['Sales'].sum()).reset_index()
cluster2015 = pd.DataFrame(segment[segment['Year'] == 2015][['Member_number','Sales','Year']].groupby(['Member_number','Year'])['Sales'].sum()).reset_index()

# %%
from sklearn.cluster import KMeans

#within-cluster sum of square
wcss = []
for k in range(1,11):
    kmeans = KMeans(n_clusters=k, init="k-means++")
    kmeans.fit(cluster2014.iloc[:,1:])
    wcss.append(kmeans.inertia_)
plt.figure(figsize=(12,6))    
plt.grid()
plt.plot(range(1,11),wcss, linewidth=2, color="red", marker ="8")
plt.xlabel("K Value")
plt.xticks(np.arange(1,11,1))
plt.ylabel("WCSS")
plt.show()

# %%
km = KMeans(n_clusters=5)

years = [cluster2014,cluster2015]
for i in years:
    clusters = km.fit_predict(i.iloc[:,1:])
    i["Cluster"] = clusters

from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
cluster2014['Cluster'].value_counts()
# Out:
# 1    1232
# 4    1017
# 2     731
# 0     385
# 3      78
# Name: Cluster, dtype: int64

# %%
cluster2015['Cluster'].value_counts()
# Out:
# 3    1360
# 1    1043
# 0     588
# 2     267
# 4      56
# Name: Cluster, dtype: int64

# %%
cluster2014
# Out:
#       Member_number  Year   Sales  Cluster
# 0              1000  2014   43.23        1
# 1              1001  2014   60.30        4
# 2              1002  2014   88.78        4
# 3              1003  2014   45.73        1
# 4              1004  2014  275.55        3
# ...             ...   ...     ...      ...
# 3438           4993  2014  110.07        2
# 3439           4995  2014   52.75        4
# 3440           4997  2014   20.04        1
# 3441           4999  2014   26.19        1
# 3442           5000  2014   60.47        4
#
# [3443 rows x 4 columns]

# %%
cluster2015
# Out:
#       Member_number  Year   Sales  Cluster
# 0              1000  2015  179.43        0
# 1              1001  2015   69.64        1
# 2              1002  2015   32.26        3
# 3              1003  2015   21.48        3
# 4              1004  2015   49.20        3
# ...             ...   ...     ...      ...
# 3309           4996  2015   97.97        1
# 3310           4997  2015   71.67        1
# 3311           4998  2015   13.80        3
# 3312           4999  2015  163.68        0
# 3313           5000  2015   34.07        3
#
# [3314 rows x 4 columns]

# %%
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
 

fig = plt.figure(figsize=(20,10))
ax = fig.add_subplot(111, projection='3d')
ax.scatter(cluster2014.Year[cluster2014.Cluster == 0], cluster2014["Sales"][cluster2014.Cluster == 0], c='blue', s=60)
ax.scatter(cluster2015.Year[cluster2015.Cluster == 1], cluster2015["Sales"][cluster2015.Cluster == 1], c='red', s=60)
ax.view_init(30, 185)
plt.xlabel("Quantity")
plt.ylabel("Sales")
plt.show()

# %%
cluster2014[cluster2014['Cluster'] == 0].describe()
# Out:
#        Member_number    Year       Sales  Cluster
# count     385.000000   385.0  385.000000    385.0
# mean     3071.405195  2014.0  183.034234      0.0
# std      1162.843884     0.0   22.071169      0.0
# min      1010.000000  2014.0  152.160000      0.0
# 25%      2029.000000  2014.0  164.840000      0.0
# 50%      3123.000000  2014.0  178.340000      0.0
# 75%      4090.000000  2014.0  199.000000      0.0
# max      4991.000000  2014.0  235.630000      0.0

# %%
cluster2014[cluster2014['Cluster'] == 1].describe()
# Out:
#        Member_number    Year        Sales  Cluster
# count    1232.000000  1232.0  1232.000000   1232.0
# mean     2992.788149  2014.0    28.939253      1.0
# std      1162.526371     0.0    12.191965      0.0
# min      1000.000000  2014.0     2.030000      1.0
# 25%      1969.500000  2014.0    19.217500      1.0
# 50%      2991.000000  2014.0    29.335000      1.0
# 75%      4002.750000  2014.0    39.277500      1.0
# max      4999.000000  2014.0    50.200000      1.0

# %%
cluster2014[cluster2014['Cluster'] == 2].describe()
# Out:
#        Member_number    Year       Sales  Cluster
# count     731.000000   731.0  731.000000    731.0
# mean     3053.266758  2014.0  120.543776      2.0
# std      1162.643630     0.0   15.508247      0.0
# min      1006.000000  2014.0   96.080000      2.0
# 25%      2074.500000  2014.0  107.330000      2.0
# 50%      3100.000000  2014.0  119.260000      2.0
# 75%      4074.000000  2014.0  133.075000      2.0
# max      4993.000000  2014.0  151.450000      2.0

# %%
cluster2014[cluster2014['Cluster'] == 3].describe()
# Out:
#        Member_number    Year       Sales  Cluster
# count      78.000000    78.0   78.000000     78.0
# mean     2832.717949  2014.0  290.168462      3.0
# std      1184.804800     0.0   66.761729      0.0
# min      1004.000000  2014.0  236.670000      3.0
# 25%      1873.500000  2014.0  248.390000      3.0
# 50%      2673.500000  2014.0  265.840000      3.0
# 75%      3830.000000  2014.0  301.587500      3.0
# max      4969.000000  2014.0  540.250000      3.0

# %%
cluster2014[cluster2014['Cluster'] == 4].describe()
# Out:
#        Member_number    Year        Sales  Cluster
# count    1017.000000  1017.0  1017.000000   1017.0
# mean     2968.468043  2014.0    71.702311      4.0
# std      1138.597410     0.0    13.190133      0.0
# min      1001.000000  2014.0    50.320000      4.0
# 25%      1972.000000  2014.0    60.420000      4.0
# 50%      2928.000000  2014.0    70.640000      4.0
# 75%      3950.000000  2014.0    82.410000      4.0
# max      5000.000000  2014.0    96.020000      4.0

# %% [raw]
# # Cluster Naming Explanation
#
# Cluster 0 (Average-Customer):- Customer who are spending above 100 and Maximum 150
# Cluster 1 (Low-Value-Customer):- Customer who are spending above 2 and Maximum 50
# Cluster 2 (Upper-High-Value-Customer):- Customer who are spending above 250 and Maximum 550
# Cluster 3 (High-Value-Customer):- Customer who are spending above 150 and Maximum 250
# Cluster 4 (Upper-Low-Value-Customer):- Customer who are spending above 50 and Maximum 100

# %%
cluster2014['Cluster'] = cluster2014['Cluster'].replace({4:'Upper-Low-Value-Customer',2:'Upper-High-Value-Customer',0:'Average-Customer',1:'Low-Value-Customer',3:'High-Value-Customer'})
cluster2015['Cluster'] = cluster2015['Cluster'].replace({4:'Upper-Low-Value-Customer',2:'Upper-High-Value-Customer',0:'Average-Customer',1:'Low-Value-Customer',3:'High-Value-Customer'})

# %%
cluster2014
# Out:
#       Member_number  Year   Sales                    Cluster
# 0              1000  2014   43.23         Low-Value-Customer
# 1              1001  2014   60.30   Upper-Low-Value-Customer
# 2              1002  2014   88.78   Upper-Low-Value-Customer
# 3              1003  2014   45.73         Low-Value-Customer
# 4              1004  2014  275.55        High-Value-Customer
# ...             ...   ...     ...                        ...
# 3438           4993  2014  110.07  Upper-High-Value-Customer
# 3439           4995  2014   52.75   Upper-Low-Value-Customer
# 3440           4997  2014   20.04         Low-Value-Customer
# 3441           4999  2014   26.19         Low-Value-Customer
# 3442           5000  2014   60.47   Upper-Low-Value-Customer
#
# [3443 rows x 4 columns]

# %%
cluster2015
# Out:
#       Member_number  Year   Sales              Cluster
# 0              1000  2015  179.43     Average-Customer
# 1              1001  2015   69.64   Low-Value-Customer
# 2              1002  2015   32.26  High-Value-Customer
# 3              1003  2015   21.48  High-Value-Customer
# 4              1004  2015   49.20  High-Value-Customer
# ...             ...   ...     ...                  ...
# 3309           4996  2015   97.97   Low-Value-Customer
# 3310           4997  2015   71.67   Low-Value-Customer
# 3311           4998  2015   13.80  High-Value-Customer
# 3312           4999  2015  163.68     Average-Customer
# 3313           5000  2015   34.07  High-Value-Customer
#
# [3314 rows x 4 columns]

# %%
cluster2014['Cluster'].value_counts()
# Out:
# Low-Value-Customer           1232
# Upper-Low-Value-Customer     1017
# Upper-High-Value-Customer     731
# Average-Customer              385
# High-Value-Customer            78
# Name: Cluster, dtype: int64

# %%
cluster2015['Cluster'].value_counts()
# Out:
# High-Value-Customer          1360
# Low-Value-Customer           1043
# Average-Customer              588
# Upper-High-Value-Customer     267
# Upper-Low-Value-Customer       56
# Name: Cluster, dtype: int64

# %%
sns.countplot(cluster2014['Cluster'].value_counts())
# Out:
# <AxesSubplot:xlabel='Cluster', ylabel='count'>

# %%
sns.countplot(cluster2015['Cluster'].value_counts())
# Out:
# <AxesSubplot:xlabel='Cluster', ylabel='count'>

# %%
finalcluster = cluster2014[['Member_number','Cluster']].rename({'Cluster':'2014'})
finalcluster['2015'] = cluster2015['Cluster'].rename({'Cluster':'2015'})
finalcluster.rename({'Cluster':'2014'},axis = 1,inplace = True)
finalcluster.fillna("No-Transactions",inplace = True)

# %%
finalcluster
# Out:
#       Member_number                       2014                 2015
# 0              1000         Low-Value-Customer     Average-Customer
# 1              1001   Upper-Low-Value-Customer   Low-Value-Customer
# 2              1002   Upper-Low-Value-Customer  High-Value-Customer
# 3              1003         Low-Value-Customer  High-Value-Customer
# 4              1004        High-Value-Customer  High-Value-Customer
# ...             ...                        ...                  ...
# 3438           4993  Upper-High-Value-Customer      No-Transactions
# 3439           4995   Upper-Low-Value-Customer      No-Transactions
# 3440           4997         Low-Value-Customer      No-Transactions
# 3441           4999         Low-Value-Customer      No-Transactions
# 3442           5000   Upper-Low-Value-Customer      No-Transactions
#
# [3443 rows x 3 columns]

# %%
From_2014_2015 = pd.crosstab(finalcluster['2014'], finalcluster['2015'])

# %%
From_2014_2015
# Out:
# 2015                       Average-Customer  High-Value-Customer  \
# 2014
# Average-Customer                         55                  163
# High-Value-Customer                       8                   34
# Low-Value-Customer                      206                  469
# Upper-High-Value-Customer               123                  288
# Upper-Low-Value-Customer                196                  406
#
# 2015                       Low-Value-Customer  No-Transactions  \
# 2014
# Average-Customer                          122               15
# High-Value-Customer                        24                2
# Low-Value-Customer                        381               49
# Upper-High-Value-Customer                 223               29
# Upper-Low-Value-Customer                  293               34
#
# 2015                       Upper-High-Value-Customer  Upper-Low-Value-Customer
# 2014
# Average-Customer                                  28                         2
# High-Value-Customer                                9                         1
# Low-Value-Customer                               101                        26
# Upper-High-Value-Customer                         53                        15
# Upper-Low-Value-Customer                          76                        12

# %%
# Create heatmap
sns.set (rc = {'figure.figsize':(5,5)})
sns.heatmap(From_2014_2015, annot=True, cmap='YlGnBu')
# Set plot labels and title
plt.xlabel('Cluster 2')
plt.ylabel('Cluster 1')
plt.title('Cluster Transitions')
# Show the heatmap
plt.show()
# Out:
# C:\Users\pc\anaconda3\lib\site-packages\seaborn\rcmod.py:400: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   if LooseVersion(mpl.__version__) >= "3.0":
# C:\Users\pc\anaconda3\lib\site-packages\setuptools\_distutils\version.py:346: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   other = LooseVersion(other)
# C:\Users\pc\anaconda3\lib\site-packages\seaborn\matrix.py:302: MatplotlibDeprecationWarning: Auto-removal of grids by pcolor() and pcolormesh() is deprecated since 3.5 and will be removed two minor releases later; please call grid(False) first.
#   mesh = ax.pcolormesh(self.plot_data, cmap=self.cmap, **kws)
# C:\Users\pc\anaconda3\lib\site-packages\seaborn\matrix.py:312: MatplotlibDeprecationWarning: Auto-removal of grids by pcolor() and pcolormesh() is deprecated since 3.5 and will be removed two minor releases later; please call grid(False) first.
#   cb = ax.figure.colorbar(mesh, cax, ax, **self.cbar_kws)
